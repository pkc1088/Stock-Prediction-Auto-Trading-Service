# %%
# !pip install yfinance
# !pip install mplfinance
# Out:
# Collecting yfinance==0.2.58
#   Downloading yfinance-0.2.58-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\user\anaconda3\lib\site-packages (from yfinance==0.2.58) (0.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.58) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\user\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance==0.2.58) (1.16.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\user\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance==0.2.58) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance==0.2.58) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance==0.2.58) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance==0.2.58) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance==0.2.58) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance==0.2.58) (2.2.2)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance==0.2.58) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance==0.2.58) (1.16.0)
# Downloading yfinance-0.2.58-py2.py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.7 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.7 kB ? eta -:--:--
#    -------------------------------- ------- 92.2/113.7 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 113.7/113.7 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.54
#     Uninstalling yfinance-0.2.54:
#       Successfully uninstalled yfinance-0.2.54
# Successfully installed yfinance-0.2.58
# Requirement already satisfied: mplfinance in c:\users\user\anaconda3\lib\site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from mplfinance) (3.8.4)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from mplfinance) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas->mplfinance) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)

# %%
# !pip install --upgrade yfinance==0.2.58

# %%
# 학습용 2014~2024 10년치 데이터

import os
import yfinance as yf
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

# 저장할 디렉토리 설정
data_dir = "./data/sp500_stocks"
os.makedirs(data_dir, exist_ok=True)

# S&P 500 종목 리스트 가져오기 (Wikipedia 사용)
def get_sp500_tickers():
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url)
    sp500_df = tables[0]  # 첫 번째 테이블이 S&P 500 리스트
    sp500_tickers = sp500_df["Symbol"].tolist()  # 'Symbol' 컬럼이 Ticker 리스트
    sp500_tickers = [ticker.replace(".", "-") for ticker in sp500_tickers]  # Yahoo Finance에서는 '.' 대신 '-' 사용
    return sp500_tickers

# S&P 500 종목 리스트 가져오기
sp500_tickers = get_sp500_tickers()
print("S&P 500 종목 개수:", len(sp500_tickers))
print("샘플 종목 리스트:", sp500_tickers[:10])

# 다운로드할 기간 설정
start_date = "2014-01-01"
end_date = "2024-01-01"

# S&P 500 종목 데이터 다운로드 및 저장
for ticker in sp500_tickers:
    try:
        print(f"{ticker} 데이터 다운로드 중...")
        df = yf.download(ticker, start=start_date, end=end_date)

        if not df.empty:
            df.to_csv(f"{data_dir}/{ticker}.csv")
            print(f"{ticker} 주가 데이터 저장 완료")
        else:
            print(f"{ticker} 데이터가 없습니다. 스킵")

        time.sleep(1)  # Yahoo Finance API 요청 간 1초 대기
    except Exception as e:
        print(f"{ticker} 데이터 다운로드 중 오류 발생: {e}")

print("S&P 500 종목 전체 주가 데이터 다운로드 완료!")
# Out:
# S&P 500 종목 개수: 503
# 샘플 종목 리스트: ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A']
# MMM 데이터 다운로드 중...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MMM']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# MMM 데이터가 없습니다. 스킵
# AOS 데이터 다운로드 중...
# KeyboardInterrupt

# %%
# 엑셀 파일 정규화

import os
import pandas as pd

# 저장된 CSV 파일 경로 (폴더 확인)
data_dir = "./data/sp500_stocks/"

# 폴더가 존재하는지 확인하고 없으면 오류 메시지 출력
if not os.path.exists(data_dir):
    print(f"오류: {data_dir} 폴더가 존재하지 않습니다. CSV 파일이 저장된 폴더를 확인하세요.")
else:
    # 모든 CSV 파일 가져오기
    csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

    # 올바른 컬럼명 지정 (Yahoo Finance 기본 구조)
    correct_columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

    # 모든 CSV 파일을 수정
    for csv_file in csv_files:
        file_path = os.path.join(data_dir, csv_file)

        print(f"{csv_file} 파일 수정 중...")

        try:
            # CSV 파일 로드
            df = pd.read_csv(file_path, skiprows=3, names=correct_columns)  # 첫 행을 컬럼으로 지정

            # 데이터 타입 변환 (문자열 → 숫자)
            numeric_columns = ['Close', 'High', 'Low', 'Open', 'Volume']
            df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

            # 수정된 데이터 다시 저장
            df.to_csv(file_path, index=False)

            print(f"{csv_file} 수정 완료")

        except Exception as e:
            print(f"{csv_file} 수정 중 오류 발생: {e}")

    print("모든 CSV 파일 수정 완료!")
# Out:
# A.csv 파일 수정 중...
# A.csv 수정 완료
# AAPL.csv 파일 수정 중...
# AAPL.csv 수정 완료
# ABBV.csv 파일 수정 중...
# ABBV.csv 수정 완료
# ABNB.csv 파일 수정 중...
# ABNB.csv 수정 완료
# ABT.csv 파일 수정 중...
# ABT.csv 수정 완료
# ACGL.csv 파일 수정 중...
# ACGL.csv 수정 완료
# ACN.csv 파일 수정 중...
# ACN.csv 수정 완료
# ADBE.csv 파일 수정 중...
# ADBE.csv 수정 완료
# ADI.csv 파일 수정 중...
# ADI.csv 수정 완료
# ADM.csv 파일 수정 중...
# ADM.csv 수정 완료
# ADP.csv 파일 수정 중...
# ADP.csv 수정 완료
# ADSK.csv 파일 수정 중...
# ADSK.csv 수정 완료
# AEE.csv 파일 수정 중...
# AEE.csv 수정 완료
# AEP.csv 파일 수정 중...
# AEP.csv 수정 완료
# AES.csv 파일 수정 중...
# AES.csv 수정 완료
# AFL.csv 파일 수정 중...
# AFL.csv 수정 완료
# AIG.csv 파일 수정 중...
# AIG.csv 수정 완료
# AIZ.csv 파일 수정 중...
# AIZ.csv 수정 완료
# AJG.csv 파일 수정 중...
# AJG.csv 수정 완료
# AKAM.csv 파일 수정 중...
# AKAM.csv 수정 완료
# ALB.csv 파일 수정 중...
# ALB.csv 수정 완료
# ALGN.csv 파일 수정 중...
# ALGN.csv 수정 완료
# ALL.csv 파일 수정 중...
# ALL.csv 수정 완료
# ALLE.csv 파일 수정 중...
# ALLE.csv 수정 완료
# AMAT.csv 파일 수정 중...
# AMAT.csv 수정 완료
# AMCR.csv 파일 수정 중...
# AMCR.csv 수정 완료
# AMD.csv 파일 수정 중...
# AMD.csv 수정 완료
# AME.csv 파일 수정 중...
# AME.csv 수정 완료
# AMGN.csv 파일 수정 중...
# AMGN.csv 수정 완료
# AMP.csv 파일 수정 중...
# AMP.csv 수정 완료
# AMT.csv 파일 수정 중...
# AMT.csv 수정 완료
# AMZN.csv 파일 수정 중...
# AMZN.csv 수정 완료
# ANET.csv 파일 수정 중...
# ANET.csv 수정 완료
# ANSS.csv 파일 수정 중...
# ANSS.csv 수정 완료
# AON.csv 파일 수정 중...
# AON.csv 수정 완료
# AOS.csv 파일 수정 중...
# AOS.csv 수정 완료
# APA.csv 파일 수정 중...
# APA.csv 수정 완료
# APD.csv 파일 수정 중...
# APD.csv 수정 완료
# APH.csv 파일 수정 중...
# APH.csv 수정 완료
# APO.csv 파일 수정 중...
# APO.csv 수정 완료
# APTV.csv 파일 수정 중...
# APTV.csv 수정 완료
# ARE.csv 파일 수정 중...
# ARE.csv 수정 완료
# ATO.csv 파일 수정 중...
# ATO.csv 수정 완료
# AVB.csv 파일 수정 중...
# AVB.csv 수정 완료
# AVGO.csv 파일 수정 중...
# AVGO.csv 수정 완료
# AVY.csv 파일 수정 중...
# AVY.csv 수정 완료
# AWK.csv 파일 수정 중...
# AWK.csv 수정 완료
# AXON.csv 파일 수정 중...
# AXON.csv 수정 완료
# AXP.csv 파일 수정 중...
# AXP.csv 수정 완료
# AZO.csv 파일 수정 중...
# AZO.csv 수정 완료
# BA.csv 파일 수정 중...
# BA.csv 수정 완료
# BAC.csv 파일 수정 중...
# BAC.csv 수정 완료
# BALL.csv 파일 수정 중...
# BALL.csv 수정 완료
# BAX.csv 파일 수정 중...
# BAX.csv 수정 완료
# BBY.csv 파일 수정 중...
# BBY.csv 수정 완료
# BDX.csv 파일 수정 중...
# BDX.csv 수정 완료
# BEN.csv 파일 수정 중...
# BEN.csv 수정 완료
# BF-B.csv 파일 수정 중...
# BF-B.csv 수정 완료
# BG.csv 파일 수정 중...
# BG.csv 수정 완료
# BIIB.csv 파일 수정 중...
# BIIB.csv 수정 완료
# BK.csv 파일 수정 중...
# BK.csv 수정 완료
# BKNG.csv 파일 수정 중...
# BKNG.csv 수정 완료
# BKR.csv 파일 수정 중...
# BKR.csv 수정 완료
# BLDR.csv 파일 수정 중...
# BLDR.csv 수정 완료
# BLK.csv 파일 수정 중...
# BLK.csv 수정 완료
# BMY.csv 파일 수정 중...
# BMY.csv 수정 완료
# BR.csv 파일 수정 중...
# BR.csv 수정 완료
# BRK-B.csv 파일 수정 중...
# BRK-B.csv 수정 완료
# BRO.csv 파일 수정 중...
# BRO.csv 수정 완료
# BSX.csv 파일 수정 중...
# BSX.csv 수정 완료
# BX.csv 파일 수정 중...
# BX.csv 수정 완료
# BXP.csv 파일 수정 중...
# BXP.csv 수정 완료
# C.csv 파일 수정 중...
# C.csv 수정 완료
# CAG.csv 파일 수정 중...
# CAG.csv 수정 완료
# CAH.csv 파일 수정 중...
# CAH.csv 수정 완료
# CARR.csv 파일 수정 중...
# CARR.csv 수정 완료
# CAT.csv 파일 수정 중...
# CAT.csv 수정 완료
# CB.csv 파일 수정 중...
# CB.csv 수정 완료
# CBOE.csv 파일 수정 중...
# CBOE.csv 수정 완료
# CBRE.csv 파일 수정 중...
# CBRE.csv 수정 완료
# CCI.csv 파일 수정 중...
# CCI.csv 수정 완료
# CCL.csv 파일 수정 중...
# CCL.csv 수정 완료
# CDNS.csv 파일 수정 중...
# CDNS.csv 수정 완료
# CDW.csv 파일 수정 중...
# CDW.csv 수정 완료
# CEG.csv 파일 수정 중...
# CEG.csv 수정 완료
# CF.csv 파일 수정 중...
# CF.csv 수정 완료
# CFG.csv 파일 수정 중...
# CFG.csv 수정 완료
# CHD.csv 파일 수정 중...
# CHD.csv 수정 완료
# CHRW.csv 파일 수정 중...
# CHRW.csv 수정 완료
# CHTR.csv 파일 수정 중...
# CHTR.csv 수정 완료
# CI.csv 파일 수정 중...
# CI.csv 수정 완료
# CINF.csv 파일 수정 중...
# CINF.csv 수정 완료
# CL.csv 파일 수정 중...
# CL.csv 수정 완료
# CLX.csv 파일 수정 중...
# CLX.csv 수정 완료
# CMCSA.csv 파일 수정 중...
# CMCSA.csv 수정 완료
# CME.csv 파일 수정 중...
# CME.csv 수정 완료
# CMG.csv 파일 수정 중...
# CMG.csv 수정 완료
# CMI.csv 파일 수정 중...
# CMI.csv 수정 완료
# CMS.csv 파일 수정 중...
# CMS.csv 수정 완료
# CNC.csv 파일 수정 중...
# CNC.csv 수정 완료
# CNP.csv 파일 수정 중...
# CNP.csv 수정 완료
# COF.csv 파일 수정 중...
# COF.csv 수정 완료
# COO.csv 파일 수정 중...
# COO.csv 수정 완료
# COP.csv 파일 수정 중...
# COP.csv 수정 완료
# COR.csv 파일 수정 중...
# COR.csv 수정 완료
# COST.csv 파일 수정 중...
# COST.csv 수정 완료
# CPAY.csv 파일 수정 중...
# CPAY.csv 수정 완료
# CPB.csv 파일 수정 중...
# CPB.csv 수정 완료
# CPRT.csv 파일 수정 중...
# CPRT.csv 수정 완료
# CPT.csv 파일 수정 중...
# CPT.csv 수정 완료
# CRL.csv 파일 수정 중...
# CRL.csv 수정 완료
# CRM.csv 파일 수정 중...
# CRM.csv 수정 완료
# CRWD.csv 파일 수정 중...
# CRWD.csv 수정 완료
# CSCO.csv 파일 수정 중...
# CSCO.csv 수정 완료
# CSGP.csv 파일 수정 중...
# CSGP.csv 수정 완료
# CSX.csv 파일 수정 중...
# CSX.csv 수정 완료
# CTAS.csv 파일 수정 중...
# CTAS.csv 수정 완료
# CTRA.csv 파일 수정 중...
# CTRA.csv 수정 완료
# CTSH.csv 파일 수정 중...
# CTSH.csv 수정 완료
# CTVA.csv 파일 수정 중...
# CTVA.csv 수정 완료
# CVS.csv 파일 수정 중...
# CVS.csv 수정 완료
# CVX.csv 파일 수정 중...
# CVX.csv 수정 완료
# CZR.csv 파일 수정 중...
# CZR.csv 수정 완료
# D.csv 파일 수정 중...
# D.csv 수정 완료
# DAL.csv 파일 수정 중...
# DAL.csv 수정 완료
# DASH.csv 파일 수정 중...
# DASH.csv 수정 완료
# DAY.csv 파일 수정 중...
# DAY.csv 수정 완료
# DD.csv 파일 수정 중...
# DD.csv 수정 완료
# DE.csv 파일 수정 중...
# DE.csv 수정 완료
# DECK.csv 파일 수정 중...
# DECK.csv 수정 완료
# DELL.csv 파일 수정 중...
# DELL.csv 수정 완료
# DFS.csv 파일 수정 중...
# DFS.csv 수정 완료
# DG.csv 파일 수정 중...
# DG.csv 수정 완료
# DGX.csv 파일 수정 중...
# DGX.csv 수정 완료
# DHI.csv 파일 수정 중...
# DHI.csv 수정 완료
# DHR.csv 파일 수정 중...
# DHR.csv 수정 완료
# DIS.csv 파일 수정 중...
# DIS.csv 수정 완료
# DLR.csv 파일 수정 중...
# DLR.csv 수정 완료
# DLTR.csv 파일 수정 중...
# DLTR.csv 수정 완료
# DOC.csv 파일 수정 중...
# DOC.csv 수정 완료
# DOV.csv 파일 수정 중...
# DOV.csv 수정 완료
# DOW.csv 파일 수정 중...
# DOW.csv 수정 완료
# DPZ.csv 파일 수정 중...
# DPZ.csv 수정 완료
# DRI.csv 파일 수정 중...
# DRI.csv 수정 완료
# DTE.csv 파일 수정 중...
# DTE.csv 수정 완료
# DUK.csv 파일 수정 중...
# DUK.csv 수정 완료
# DVA.csv 파일 수정 중...
# DVA.csv 수정 완료
# DVN.csv 파일 수정 중...
# DVN.csv 수정 완료
# DXCM.csv 파일 수정 중...
# DXCM.csv 수정 완료
# EA.csv 파일 수정 중...
# EA.csv 수정 완료
# EBAY.csv 파일 수정 중...
# EBAY.csv 수정 완료
# ECL.csv 파일 수정 중...
# ECL.csv 수정 완료
# ED.csv 파일 수정 중...
# ED.csv 수정 완료
# EFX.csv 파일 수정 중...
# EFX.csv 수정 완료
# EG.csv 파일 수정 중...
# EG.csv 수정 완료
# EIX.csv 파일 수정 중...
# EIX.csv 수정 완료
# EL.csv 파일 수정 중...
# EL.csv 수정 완료
# ELV.csv 파일 수정 중...
# ELV.csv 수정 완료
# EMN.csv 파일 수정 중...
# EMN.csv 수정 완료
# EMR.csv 파일 수정 중...
# EMR.csv 수정 완료
# ENPH.csv 파일 수정 중...
# ENPH.csv 수정 완료
# EOG.csv 파일 수정 중...
# EOG.csv 수정 완료
# EPAM.csv 파일 수정 중...
# EPAM.csv 수정 완료
# EQIX.csv 파일 수정 중...
# EQIX.csv 수정 완료
# EQR.csv 파일 수정 중...
# EQR.csv 수정 완료
# EQT.csv 파일 수정 중...
# EQT.csv 수정 완료
# ERIE.csv 파일 수정 중...
# ERIE.csv 수정 완료
# ES.csv 파일 수정 중...
# ES.csv 수정 완료
# ESS.csv 파일 수정 중...
# ESS.csv 수정 완료
# ETN.csv 파일 수정 중...
# ETN.csv 수정 완료
# ETR.csv 파일 수정 중...
# ETR.csv 수정 완료
# EVRG.csv 파일 수정 중...
# EVRG.csv 수정 완료
# EW.csv 파일 수정 중...
# EW.csv 수정 완료
# EXC.csv 파일 수정 중...
# EXC.csv 수정 완료
# EXE.csv 파일 수정 중...
# EXE.csv 수정 완료
# EXPD.csv 파일 수정 중...
# EXPD.csv 수정 완료
# EXPE.csv 파일 수정 중...
# EXPE.csv 수정 완료
# EXR.csv 파일 수정 중...
# EXR.csv 수정 완료
# F.csv 파일 수정 중...
# F.csv 수정 완료
# FANG.csv 파일 수정 중...
# FANG.csv 수정 완료
# FAST.csv 파일 수정 중...
# FAST.csv 수정 완료
# FCX.csv 파일 수정 중...
# FCX.csv 수정 완료
# FDS.csv 파일 수정 중...
# FDS.csv 수정 완료
# FDX.csv 파일 수정 중...
# FDX.csv 수정 완료
# FE.csv 파일 수정 중...
# FE.csv 수정 완료
# FFIV.csv 파일 수정 중...
# FFIV.csv 수정 완료
# FI.csv 파일 수정 중...
# FI.csv 수정 완료
# FICO.csv 파일 수정 중...
# FICO.csv 수정 완료
# FIS.csv 파일 수정 중...
# FIS.csv 수정 완료
# FITB.csv 파일 수정 중...
# FITB.csv 수정 완료
# FOX.csv 파일 수정 중...
# FOX.csv 수정 완료
# FOXA.csv 파일 수정 중...
# FOXA.csv 수정 완료
# FRT.csv 파일 수정 중...
# FRT.csv 수정 완료
# FSLR.csv 파일 수정 중...
# FSLR.csv 수정 완료
# FTNT.csv 파일 수정 중...
# FTNT.csv 수정 완료
# FTV.csv 파일 수정 중...
# FTV.csv 수정 완료
# GD.csv 파일 수정 중...
# GD.csv 수정 완료
# GDDY.csv 파일 수정 중...
# GDDY.csv 수정 완료
# GE.csv 파일 수정 중...
# GE.csv 수정 완료
# GEHC.csv 파일 수정 중...
# GEHC.csv 수정 완료
# GEN.csv 파일 수정 중...
# GEN.csv 수정 완료
# GILD.csv 파일 수정 중...
# GILD.csv 수정 완료
# GIS.csv 파일 수정 중...
# GIS.csv 수정 완료
# GL.csv 파일 수정 중...
# GL.csv 수정 완료
# GLW.csv 파일 수정 중...
# GLW.csv 수정 완료
# GM.csv 파일 수정 중...
# GM.csv 수정 완료
# GNRC.csv 파일 수정 중...
# GNRC.csv 수정 완료
# GOOG.csv 파일 수정 중...
# GOOG.csv 수정 완료
# GOOGL.csv 파일 수정 중...
# GOOGL.csv 수정 완료
# GPC.csv 파일 수정 중...
# GPC.csv 수정 완료
# GPN.csv 파일 수정 중...
# GPN.csv 수정 완료
# GRMN.csv 파일 수정 중...
# GRMN.csv 수정 완료
# GS.csv 파일 수정 중...
# GS.csv 수정 완료
# GWW.csv 파일 수정 중...
# GWW.csv 수정 완료
# HAL.csv 파일 수정 중...
# HAL.csv 수정 완료
# HAS.csv 파일 수정 중...
# HAS.csv 수정 완료
# HBAN.csv 파일 수정 중...
# HBAN.csv 수정 완료
# HCA.csv 파일 수정 중...
# HCA.csv 수정 완료
# HD.csv 파일 수정 중...
# HD.csv 수정 완료
# HES.csv 파일 수정 중...
# HES.csv 수정 완료
# HIG.csv 파일 수정 중...
# HIG.csv 수정 완료
# HII.csv 파일 수정 중...
# HII.csv 수정 완료
# HLT.csv 파일 수정 중...
# HLT.csv 수정 완료
# HOLX.csv 파일 수정 중...
# HOLX.csv 수정 완료
# HON.csv 파일 수정 중...
# HON.csv 수정 완료
# HPE.csv 파일 수정 중...
# HPE.csv 수정 완료
# HPQ.csv 파일 수정 중...
# HPQ.csv 수정 완료
# HRL.csv 파일 수정 중...
# HRL.csv 수정 완료
# HSIC.csv 파일 수정 중...
# HSIC.csv 수정 완료
# HST.csv 파일 수정 중...
# HST.csv 수정 완료
# HSY.csv 파일 수정 중...
# HSY.csv 수정 완료
# HUBB.csv 파일 수정 중...
# HUBB.csv 수정 완료
# HUM.csv 파일 수정 중...
# HUM.csv 수정 완료
# HWM.csv 파일 수정 중...
# HWM.csv 수정 완료
# IBM.csv 파일 수정 중...
# IBM.csv 수정 완료
# ICE.csv 파일 수정 중...
# ICE.csv 수정 완료
# IDXX.csv 파일 수정 중...
# IDXX.csv 수정 완료
# IEX.csv 파일 수정 중...
# IEX.csv 수정 완료
# IFF.csv 파일 수정 중...
# IFF.csv 수정 완료
# INCY.csv 파일 수정 중...
# INCY.csv 수정 완료
# INTC.csv 파일 수정 중...
# INTC.csv 수정 완료
# INTU.csv 파일 수정 중...
# INTU.csv 수정 완료
# INVH.csv 파일 수정 중...
# INVH.csv 수정 완료
# IP.csv 파일 수정 중...
# IP.csv 수정 완료
# IPG.csv 파일 수정 중...
# IPG.csv 수정 완료
# IQV.csv 파일 수정 중...
# IQV.csv 수정 완료
# IR.csv 파일 수정 중...
# IR.csv 수정 완료
# IRM.csv 파일 수정 중...
# IRM.csv 수정 완료
# ISRG.csv 파일 수정 중...
# ISRG.csv 수정 완료
# IT.csv 파일 수정 중...
# IT.csv 수정 완료
# ITW.csv 파일 수정 중...
# ITW.csv 수정 완료
# IVZ.csv 파일 수정 중...
# IVZ.csv 수정 완료
# J.csv 파일 수정 중...
# J.csv 수정 완료
# JBHT.csv 파일 수정 중...
# JBHT.csv 수정 완료
# JBL.csv 파일 수정 중...
# JBL.csv 수정 완료
# JCI.csv 파일 수정 중...
# JCI.csv 수정 완료
# JKHY.csv 파일 수정 중...
# JKHY.csv 수정 완료
# JNJ.csv 파일 수정 중...
# JNJ.csv 수정 완료
# JNPR.csv 파일 수정 중...
# JNPR.csv 수정 완료
# JPM.csv 파일 수정 중...
# JPM.csv 수정 완료
# K.csv 파일 수정 중...
# K.csv 수정 완료
# KDP.csv 파일 수정 중...
# KDP.csv 수정 완료
# KEY.csv 파일 수정 중...
# KEY.csv 수정 완료
# KEYS.csv 파일 수정 중...
# KEYS.csv 수정 완료
# KHC.csv 파일 수정 중...
# KHC.csv 수정 완료
# KIM.csv 파일 수정 중...
# KIM.csv 수정 완료
# KKR.csv 파일 수정 중...
# KKR.csv 수정 완료
# KLAC.csv 파일 수정 중...
# KLAC.csv 수정 완료
# KMB.csv 파일 수정 중...
# KMB.csv 수정 완료
# KMI.csv 파일 수정 중...
# KMI.csv 수정 완료
# KMX.csv 파일 수정 중...
# KMX.csv 수정 완료
# KO.csv 파일 수정 중...
# KO.csv 수정 완료
# KR.csv 파일 수정 중...
# KR.csv 수정 완료
# KVUE.csv 파일 수정 중...
# KVUE.csv 수정 완료
# L.csv 파일 수정 중...
# L.csv 수정 완료
# LDOS.csv 파일 수정 중...
# LDOS.csv 수정 완료
# LEN.csv 파일 수정 중...
# LEN.csv 수정 완료
# LH.csv 파일 수정 중...
# LH.csv 수정 완료
# LHX.csv 파일 수정 중...
# LHX.csv 수정 완료
# LII.csv 파일 수정 중...
# LII.csv 수정 완료
# LIN.csv 파일 수정 중...
# LIN.csv 수정 완료
# LKQ.csv 파일 수정 중...
# LKQ.csv 수정 완료
# LLY.csv 파일 수정 중...
# LLY.csv 수정 완료
# LMT.csv 파일 수정 중...
# LMT.csv 수정 완료
# LNT.csv 파일 수정 중...
# LNT.csv 수정 완료
# LOW.csv 파일 수정 중...
# LOW.csv 수정 완료
# LRCX.csv 파일 수정 중...
# LRCX.csv 수정 완료
# LULU.csv 파일 수정 중...
# LULU.csv 수정 완료
# LUV.csv 파일 수정 중...
# LUV.csv 수정 완료
# LVS.csv 파일 수정 중...
# LVS.csv 수정 완료
# LW.csv 파일 수정 중...
# LW.csv 수정 완료
# LYB.csv 파일 수정 중...
# LYB.csv 수정 완료
# LYV.csv 파일 수정 중...
# LYV.csv 수정 완료
# MA.csv 파일 수정 중...
# MA.csv 수정 완료
# MAA.csv 파일 수정 중...
# MAA.csv 수정 완료
# MAR.csv 파일 수정 중...
# MAR.csv 수정 완료
# MAS.csv 파일 수정 중...
# MAS.csv 수정 완료
# MCD.csv 파일 수정 중...
# MCD.csv 수정 완료
# MCHP.csv 파일 수정 중...
# MCHP.csv 수정 완료
# MCK.csv 파일 수정 중...
# MCK.csv 수정 완료
# MCO.csv 파일 수정 중...
# MCO.csv 수정 완료
# MDLZ.csv 파일 수정 중...
# MDLZ.csv 수정 완료
# MDT.csv 파일 수정 중...
# MDT.csv 수정 완료
# MET.csv 파일 수정 중...
# MET.csv 수정 완료
# META.csv 파일 수정 중...
# META.csv 수정 완료
# MGM.csv 파일 수정 중...
# MGM.csv 수정 완료
# MHK.csv 파일 수정 중...
# MHK.csv 수정 완료
# MKC.csv 파일 수정 중...
# MKC.csv 수정 완료
# MKTX.csv 파일 수정 중...
# MKTX.csv 수정 완료
# MLM.csv 파일 수정 중...
# MLM.csv 수정 완료
# MMC.csv 파일 수정 중...
# MMC.csv 수정 완료
# MMM.csv 파일 수정 중...
# MMM.csv 수정 완료
# MNST.csv 파일 수정 중...
# MNST.csv 수정 완료
# MO.csv 파일 수정 중...
# MO.csv 수정 완료
# MOH.csv 파일 수정 중...
# MOH.csv 수정 완료
# MOS.csv 파일 수정 중...
# MOS.csv 수정 완료
# MPC.csv 파일 수정 중...
# MPC.csv 수정 완료
# MPWR.csv 파일 수정 중...
# MPWR.csv 수정 완료
# MRK.csv 파일 수정 중...
# MRK.csv 수정 완료
# MRNA.csv 파일 수정 중...
# MRNA.csv 수정 완료
# MS.csv 파일 수정 중...
# MS.csv 수정 완료
# MSCI.csv 파일 수정 중...
# MSCI.csv 수정 완료
# MSFT.csv 파일 수정 중...
# MSFT.csv 수정 완료
# MSI.csv 파일 수정 중...
# MSI.csv 수정 완료
# MTB.csv 파일 수정 중...
# MTB.csv 수정 완료
# MTCH.csv 파일 수정 중...
# MTCH.csv 수정 완료
# MTD.csv 파일 수정 중...
# MTD.csv 수정 완료
# MU.csv 파일 수정 중...
# MU.csv 수정 완료
# NCLH.csv 파일 수정 중...
# NCLH.csv 수정 완료
# NDAQ.csv 파일 수정 중...
# NDAQ.csv 수정 완료
# NDSN.csv 파일 수정 중...
# NDSN.csv 수정 완료
# NEE.csv 파일 수정 중...
# NEE.csv 수정 완료
# NEM.csv 파일 수정 중...
# NEM.csv 수정 완료
# NFLX.csv 파일 수정 중...
# NFLX.csv 수정 완료
# NI.csv 파일 수정 중...
# NI.csv 수정 완료
# NKE.csv 파일 수정 중...
# NKE.csv 수정 완료
# NOC.csv 파일 수정 중...
# NOC.csv 수정 완료
# NOW.csv 파일 수정 중...
# NOW.csv 수정 완료
# NRG.csv 파일 수정 중...
# NRG.csv 수정 완료
# NSC.csv 파일 수정 중...
# NSC.csv 수정 완료
# NTAP.csv 파일 수정 중...
# NTAP.csv 수정 완료
# NTRS.csv 파일 수정 중...
# NTRS.csv 수정 완료
# NUE.csv 파일 수정 중...
# NUE.csv 수정 완료
# NVDA.csv 파일 수정 중...
# NVDA.csv 수정 완료
# NVR.csv 파일 수정 중...
# NVR.csv 수정 완료
# NWS.csv 파일 수정 중...
# NWS.csv 수정 완료
# NWSA.csv 파일 수정 중...
# NWSA.csv 수정 완료
# NXPI.csv 파일 수정 중...
# NXPI.csv 수정 완료
# O.csv 파일 수정 중...
# O.csv 수정 완료
# ODFL.csv 파일 수정 중...
# ODFL.csv 수정 완료
# OKE.csv 파일 수정 중...
# OKE.csv 수정 완료
# OMC.csv 파일 수정 중...
# OMC.csv 수정 완료
# ON.csv 파일 수정 중...
# ON.csv 수정 완료
# ORCL.csv 파일 수정 중...
# ORCL.csv 수정 완료
# ORLY.csv 파일 수정 중...
# ORLY.csv 수정 완료
# OTIS.csv 파일 수정 중...
# OTIS.csv 수정 완료
# OXY.csv 파일 수정 중...
# OXY.csv 수정 완료
# PANW.csv 파일 수정 중...
# PANW.csv 수정 완료
# PARA.csv 파일 수정 중...
# PARA.csv 수정 완료
# PAYC.csv 파일 수정 중...
# PAYC.csv 수정 완료
# PAYX.csv 파일 수정 중...
# PAYX.csv 수정 완료
# PCAR.csv 파일 수정 중...
# PCAR.csv 수정 완료
# PCG.csv 파일 수정 중...
# PCG.csv 수정 완료
# PEG.csv 파일 수정 중...
# PEG.csv 수정 완료
# PEP.csv 파일 수정 중...
# PEP.csv 수정 완료
# PFE.csv 파일 수정 중...
# PFE.csv 수정 완료
# PFG.csv 파일 수정 중...
# PFG.csv 수정 완료
# PG.csv 파일 수정 중...
# PG.csv 수정 완료
# PGR.csv 파일 수정 중...
# PGR.csv 수정 완료
# PH.csv 파일 수정 중...
# PH.csv 수정 완료
# PHM.csv 파일 수정 중...
# PHM.csv 수정 완료
# PKG.csv 파일 수정 중...
# PKG.csv 수정 완료
# PLD.csv 파일 수정 중...
# PLD.csv 수정 완료
# PLTR.csv 파일 수정 중...
# PLTR.csv 수정 완료
# PM.csv 파일 수정 중...
# PM.csv 수정 완료
# PNC.csv 파일 수정 중...
# PNC.csv 수정 완료
# PNR.csv 파일 수정 중...
# PNR.csv 수정 완료
# PNW.csv 파일 수정 중...
# PNW.csv 수정 완료
# PODD.csv 파일 수정 중...
# PODD.csv 수정 완료
# POOL.csv 파일 수정 중...
# POOL.csv 수정 완료
# PPG.csv 파일 수정 중...
# PPG.csv 수정 완료
# PPL.csv 파일 수정 중...
# PPL.csv 수정 완료
# PRU.csv 파일 수정 중...
# PRU.csv 수정 완료
# PSA.csv 파일 수정 중...
# PSA.csv 수정 완료
# PSX.csv 파일 수정 중...
# PSX.csv 수정 완료
# PTC.csv 파일 수정 중...
# PTC.csv 수정 완료
# PWR.csv 파일 수정 중...
# PWR.csv 수정 완료
# PYPL.csv 파일 수정 중...
# PYPL.csv 수정 완료
# QCOM.csv 파일 수정 중...
# QCOM.csv 수정 완료
# RCL.csv 파일 수정 중...
# RCL.csv 수정 완료
# REG.csv 파일 수정 중...
# REG.csv 수정 완료
# REGN.csv 파일 수정 중...
# REGN.csv 수정 완료
# RF.csv 파일 수정 중...
# RF.csv 수정 완료
# RJF.csv 파일 수정 중...
# RJF.csv 수정 완료
# RL.csv 파일 수정 중...
# RL.csv 수정 완료
# RMD.csv 파일 수정 중...
# RMD.csv 수정 완료
# ROK.csv 파일 수정 중...
# ROK.csv 수정 완료
# ROL.csv 파일 수정 중...
# ROL.csv 수정 완료
# ROP.csv 파일 수정 중...
# ROP.csv 수정 완료
# ROST.csv 파일 수정 중...
# ROST.csv 수정 완료
# RSG.csv 파일 수정 중...
# RSG.csv 수정 완료
# RTX.csv 파일 수정 중...
# RTX.csv 수정 완료
# RVTY.csv 파일 수정 중...
# RVTY.csv 수정 완료
# SBAC.csv 파일 수정 중...
# SBAC.csv 수정 완료
# SBUX.csv 파일 수정 중...
# SBUX.csv 수정 완료
# SCHW.csv 파일 수정 중...
# SCHW.csv 수정 완료
# SHW.csv 파일 수정 중...
# SHW.csv 수정 완료
# SJM.csv 파일 수정 중...
# SJM.csv 수정 완료
# SLB.csv 파일 수정 중...
# SLB.csv 수정 완료
# SMCI.csv 파일 수정 중...
# SMCI.csv 수정 완료
# SNA.csv 파일 수정 중...
# SNA.csv 수정 완료
# SNPS.csv 파일 수정 중...
# SNPS.csv 수정 완료
# SO.csv 파일 수정 중...
# SO.csv 수정 완료
# SPG.csv 파일 수정 중...
# SPG.csv 수정 완료
# SPGI.csv 파일 수정 중...
# SPGI.csv 수정 완료
# SRE.csv 파일 수정 중...
# SRE.csv 수정 완료
# STE.csv 파일 수정 중...
# STE.csv 수정 완료
# STLD.csv 파일 수정 중...
# STLD.csv 수정 완료
# STT.csv 파일 수정 중...
# STT.csv 수정 완료
# STX.csv 파일 수정 중...
# STX.csv 수정 완료
# STZ.csv 파일 수정 중...
# STZ.csv 수정 완료
# SWK.csv 파일 수정 중...
# SWK.csv 수정 완료
# SWKS.csv 파일 수정 중...
# SWKS.csv 수정 완료
# SYF.csv 파일 수정 중...
# SYF.csv 수정 완료
# SYK.csv 파일 수정 중...
# SYK.csv 수정 완료
# SYY.csv 파일 수정 중...
# SYY.csv 수정 완료
# T.csv 파일 수정 중...
# T.csv 수정 완료
# TAP.csv 파일 수정 중...
# TAP.csv 수정 완료
# TDG.csv 파일 수정 중...
# TDG.csv 수정 완료
# TDY.csv 파일 수정 중...
# TDY.csv 수정 완료
# TECH.csv 파일 수정 중...
# TECH.csv 수정 완료
# TEL.csv 파일 수정 중...
# TEL.csv 수정 완료
# TER.csv 파일 수정 중...
# TER.csv 수정 완료
# TFC.csv 파일 수정 중...
# TFC.csv 수정 완료
# TGT.csv 파일 수정 중...
# TGT.csv 수정 완료
# TJX.csv 파일 수정 중...
# TJX.csv 수정 완료
# TKO.csv 파일 수정 중...
# TKO.csv 수정 완료
# TMO.csv 파일 수정 중...
# TMO.csv 수정 완료
# TMUS.csv 파일 수정 중...
# TMUS.csv 수정 완료
# TPL.csv 파일 수정 중...
# TPL.csv 수정 완료
# TPR.csv 파일 수정 중...
# TPR.csv 수정 완료
# TRGP.csv 파일 수정 중...
# TRGP.csv 수정 완료
# TRMB.csv 파일 수정 중...
# TRMB.csv 수정 완료
# TROW.csv 파일 수정 중...
# TROW.csv 수정 완료
# TRV.csv 파일 수정 중...
# TRV.csv 수정 완료
# TSCO.csv 파일 수정 중...
# TSCO.csv 수정 완료
# TSLA.csv 파일 수정 중...
# TSLA.csv 수정 완료
# TSN.csv 파일 수정 중...
# TSN.csv 수정 완료
# TT.csv 파일 수정 중...
# TT.csv 수정 완료
# TTWO.csv 파일 수정 중...
# TTWO.csv 수정 완료
# TXN.csv 파일 수정 중...
# TXN.csv 수정 완료
# TXT.csv 파일 수정 중...
# TXT.csv 수정 완료
# TYL.csv 파일 수정 중...
# TYL.csv 수정 완료
# UAL.csv 파일 수정 중...
# UAL.csv 수정 완료
# UBER.csv 파일 수정 중...
# UBER.csv 수정 완료
# UDR.csv 파일 수정 중...
# UDR.csv 수정 완료
# UHS.csv 파일 수정 중...
# UHS.csv 수정 완료
# ULTA.csv 파일 수정 중...
# ULTA.csv 수정 완료
# UNH.csv 파일 수정 중...
# UNH.csv 수정 완료
# UNP.csv 파일 수정 중...
# UNP.csv 수정 완료
# UPS.csv 파일 수정 중...
# UPS.csv 수정 완료
# URI.csv 파일 수정 중...
# URI.csv 수정 완료
# USB.csv 파일 수정 중...
# USB.csv 수정 완료
# V.csv 파일 수정 중...
# V.csv 수정 완료
# VICI.csv 파일 수정 중...
# VICI.csv 수정 완료
# VLO.csv 파일 수정 중...
# VLO.csv 수정 완료
# VLTO.csv 파일 수정 중...
# VLTO.csv 수정 완료
# VMC.csv 파일 수정 중...
# VMC.csv 수정 완료
# VRSK.csv 파일 수정 중...
# VRSK.csv 수정 완료
# VRSN.csv 파일 수정 중...
# VRSN.csv 수정 완료
# VRTX.csv 파일 수정 중...
# VRTX.csv 수정 완료
# VST.csv 파일 수정 중...
# VST.csv 수정 완료
# VTR.csv 파일 수정 중...
# VTR.csv 수정 완료
# VTRS.csv 파일 수정 중...
# VTRS.csv 수정 완료
# VZ.csv 파일 수정 중...
# VZ.csv 수정 완료
# WAB.csv 파일 수정 중...
# WAB.csv 수정 완료
# WAT.csv 파일 수정 중...
# WAT.csv 수정 완료
# WBA.csv 파일 수정 중...
# WBA.csv 수정 완료
# WBD.csv 파일 수정 중...
# WBD.csv 수정 완료
# WDAY.csv 파일 수정 중...
# WDAY.csv 수정 완료
# WDC.csv 파일 수정 중...
# WDC.csv 수정 완료
# WEC.csv 파일 수정 중...
# WEC.csv 수정 완료
# WELL.csv 파일 수정 중...
# WELL.csv 수정 완료
# WFC.csv 파일 수정 중...
# WFC.csv 수정 완료
# WM.csv 파일 수정 중...
# WM.csv 수정 완료
# WMB.csv 파일 수정 중...
# WMB.csv 수정 완료
# WMT.csv 파일 수정 중...
# WMT.csv 수정 완료
# WRB.csv 파일 수정 중...
# WRB.csv 수정 완료
# WSM.csv 파일 수정 중...
# WSM.csv 수정 완료
# WST.csv 파일 수정 중...
# WST.csv 수정 완료
# WTW.csv 파일 수정 중...
# WTW.csv 수정 완료
# WY.csv 파일 수정 중...
# WY.csv 수정 완료
# WYNN.csv 파일 수정 중...
# WYNN.csv 수정 완료
# XEL.csv 파일 수정 중...
# XEL.csv 수정 완료
# XOM.csv 파일 수정 중...
# XOM.csv 수정 완료
# XYL.csv 파일 수정 중...
# XYL.csv 수정 완료
# YUM.csv 파일 수정 중...
# YUM.csv 수정 완료
# ZBH.csv 파일 수정 중...
# ZBH.csv 수정 완료
# ZBRA.csv 파일 수정 중...
# ZBRA.csv 수정 완료
# ZTS.csv 파일 수정 중...
# ZTS.csv 수정 완료
# 모든 CSV 파일 수정 완료!

# %%
# 학습용 상승패턴 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 저장할 디렉토리 설정 (상승 패턴 이미지 저장)
output_dir = "./data/price_0to1percent_surge_patterns"
os.makedirs(output_dir, exist_ok=True)

# 저장된 CSV 파일 경로 (S&P 500 주식 데이터 폴더)
data_dir = "./data/sp500_stocks/"

# 저장된 이미지 개수 제한
MAX_IMAGES = 30000
saved_image_count = 0

# 봉 개수 설정 (전날 대비 1% 이상 오른 날 기준으로 과거 20일)
N_CANDLES = 20

# 기존 저장된 이미지 확인 (중복 방지)
existing_images = set(os.listdir(output_dir))

# 모든 CSV 파일 가져오기 (S&P 500 종목 전체 대상)
csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# 모든 CSV 파일에 대해 데이터 분석
for csv_file in csv_files:
    if saved_image_count >= MAX_IMAGES:
        print("최대 저장 개수(30000장) 도달, 저장 중단")
        break

    ticker = csv_file.replace(".csv", "")  # 종목명 추출
    file_path = os.path.join(data_dir, csv_file)

    print(f"{ticker} 데이터 로드 중...")
    df = pd.read_csv(file_path)

    # 날짜 변환 및 인덱스 설정
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    df = df[df.index >= pd.Timestamp("2014-01-01")]  # 최근 10년 데이터 사용

    # 전날 대비 0~1% 상승한 날 찾기
    df['pct_change'] = df['Open'].pct_change() * 100  # 퍼센트 변환
    surge_days = df[(df['pct_change'] > 0) & (df['pct_change'] < 1)].index # 상승한 날짜 리스트

    # 상승한 날 기준으로 과거 20일의 봉차트 저장
    for surge_date in surge_days:
        if saved_image_count >= MAX_IMAGES:
            print("최대 저장 개수(30000장) 도달, 저장 중단")
            break

        # 파일명 설정
        file_name = f"{ticker}_{surge_date.strftime('%Y-%m-%d')}.png"
        file_path = os.path.join(output_dir, file_name)

        # 중복 확인: 파일이 이미 존재하면 건너뛰기
        if file_name in existing_images:
            print(f"이미 존재하는 파일: {file_name}, 건너뜀.")
            continue

        # 해당 날짜 기준으로 과거 20일 데이터 가져오기
        end_idx = df.index.get_loc(surge_date)
        start_idx = max(end_idx - N_CANDLES, 0)  # 최소 20개 봉이 있어야 함

        if start_idx == 0:
            continue  # 데이터가 부족하면 스킵

        df_fixed = df.iloc[start_idx:end_idx]

        # 캔들스틱 차트 스타일 지정
        mc = mpf.make_marketcolors(up='g', down='r', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # 캔들스틱 차트 저장
        mpf.plot(
            df_fixed,
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=file_path
        )

        # 이미지 크기 조정 (CNN 학습용 224x224 픽셀)
        img = Image.open(file_path)
        img = img.resize((224, 224))
        img.save(file_path)

        saved_image_count += 1
        existing_images.add(file_name)  # 새로 생성된 파일 추가

print(f"총 {saved_image_count}장의 상승 패턴 이미지 저장 완료!")

# A 데이터 로드 중...
# 이미 존재하는 파일: A_2014-02-25.png, 건너뜀.

# %%
# 학습용 하락패턴 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 저장할 디렉토리 설정 (하락 패턴 이미지 저장)
output_dir = "./data/price_0to1percent_drop_patterns"
os.makedirs(output_dir, exist_ok=True)

# 저장된 CSV 파일 경로 (S&P 500 주식 데이터 폴더)
data_dir = "./data/sp500_stocks/"

# 저장된 이미지 개수 제한
MAX_IMAGES = 30000
saved_image_count = 0

# 봉 개수 설정 (전날 대비 1% 이상 하락한 날 기준으로 과거 20일)
N_CANDLES = 20

# 기존 저장된 이미지 확인 (중복 방지)
existing_images = set(os.listdir(output_dir))

# 모든 CSV 파일 가져오기 (S&P 500 종목 전체 대상)
csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# 모든 CSV 파일에 대해 데이터 분석
for csv_file in csv_files:
    if saved_image_count >= MAX_IMAGES:
        print("최대 저장 개수(30000장) 도달, 저장 중단")
        break

    ticker = csv_file.replace(".csv", "")  # 종목명 추출
    file_path = os.path.join(data_dir, csv_file)

    print(f"{ticker} 데이터 로드 중...")
    df = pd.read_csv(file_path)

    # 날짜 변환 및 인덱스 설정
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    df = df[df.index >= pd.Timestamp("2014-01-01")]  # 최근 10년 데이터 사용

    # 전날 대비 하락한 날 찾기
    df['pct_change'] = df['Open'].pct_change() * 100  # 퍼센트 변환
    drop_days = df[(df['pct_change'] < 0) & (df['pct_change'] > -1)].index  # 하락한 날짜 리스트

    # 하락한 날 기준으로 과거 20일의 봉차트 저장
    for drop_date in drop_days:
        if saved_image_count >= MAX_IMAGES:
            print("최대 저장 개수(30000장) 도달, 저장 중단")
            break

        # 파일명 설정
        file_name = f"{ticker}_{drop_date.strftime('%Y-%m-%d')}.png"
        image_path = os.path.join(output_dir, file_name)  # 이미지 저장 경로

        # 중복 확인: 파일이 이미 존재하면 건너뛰기
        if file_name in existing_images:
            #print(f"이미 존재하는 파일: {file_name}, 건너뜀.")
            continue

        # 해당 날짜 기준으로 과거 20일 데이터 가져오기
        end_idx = df.index.get_loc(drop_date)
        start_idx = max(end_idx - N_CANDLES, 0)  # 최소 20개 봉이 있어야 함

        if start_idx == 0:
            continue  # 데이터가 부족하면 스킵

        df_fixed = df.iloc[start_idx:end_idx]

        # 캔들스틱 차트 스타일 지정
        mc = mpf.make_marketcolors(up='g', down='r', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # 캔들스틱 차트 저장
        mpf.plot(
            df_fixed,
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=image_path  # 수정된 이미지 저장 경로
        )

        # 이미지 크기 조정 (CNN 학습용 224x224 픽셀)
        img = Image.open(image_path)
        img = img.resize((224, 224))
        img.save(image_path)

        saved_image_count += 1
        existing_images.add(file_name)  # 새로 생성된 파일 추가

print(f"총 {saved_image_count}장의 하락 패턴 이미지 저장 완료!")

# ABBV 데이터 로드 중...
# ABNB 데이터 로드 중...

# %%
# 테스트용 최근 1년치 데이터 ???

import os
import yfinance as yf
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

# 저장할 디렉토리 설정
data_dir = "./data/sp500_stocks_test"
os.makedirs(data_dir, exist_ok=True)

# S&P 500 종목 리스트 가져오기 (Wikipedia 사용)
def get_sp500_tickers():
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url)
    sp500_df = tables[0]  # 첫 번째 테이블이 S&P 500 리스트
    sp500_tickers = sp500_df["Symbol"].tolist()  # 'Symbol' 컬럼이 Ticker 리스트
    sp500_tickers = [ticker.replace(".", "-") for ticker in sp500_tickers]  # Yahoo Finance에서는 '.' 대신 '-' 사용
    return sp500_tickers

# S&P 500 종목 리스트 가져오기
sp500_tickers = get_sp500_tickers()
print("S&P 500 종목 개수:", len(sp500_tickers))
print("샘플 종목 리스트:", sp500_tickers[:10])

# 다운로드할 기간 설정
start_date = "2024-03-01"
end_date = "2025-04-01"

# S&P 500 종목 데이터 다운로드 및 저장
for ticker in sp500_tickers:
    try:
        print(f"{ticker} 데이터 다운로드 중...")
        df = yf.download(ticker, start=start_date, end=end_date)

        if not df.empty:
            df.to_csv(f"{data_dir}/{ticker}.csv")
            print(f"{ticker} 주가 데이터 저장 완료")
        else:
            print(f"{ticker} 데이터가 없습니다. 스킵")

        time.sleep(1)  # Yahoo Finance API 요청 간 1초 대기
    except Exception as e:
        print(f"{ticker} 데이터 다운로드 중 오류 발생: {e}")

print("S&P 500 종목 전체 주가 데이터 다운로드 완료!")

# AOS 데이터 다운로드 중...
# ABT 데이터 다운로드 중...

# %%
# 엑셀 파일 정규화

import os
import pandas as pd

# 저장된 CSV 파일 경로 (폴더 확인)
data_dir = "./data/sp500_stocks_test/"

# 폴더가 존재하는지 확인하고 없으면 오류 메시지 출력
if not os.path.exists(data_dir):
    print(f"오류: {data_dir} 폴더가 존재하지 않습니다. CSV 파일이 저장된 폴더를 확인하세요.")
else:
    # 모든 CSV 파일 가져오기
    csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

    # 올바른 컬럼명 지정 (Yahoo Finance 기본 구조)
    correct_columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

    # 모든 CSV 파일을 수정
    for csv_file in csv_files:
        file_path = os.path.join(data_dir, csv_file)

        print(f"{csv_file} 파일 수정 중...")

        try:
            # CSV 파일 로드
            df = pd.read_csv(file_path, skiprows=3, names=correct_columns)  # 첫 행을 컬럼으로 지정

            # 데이터 타입 변환 (문자열 → 숫자)
            numeric_columns = ['Close', 'High', 'Low', 'Open', 'Volume']
            df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

            # 수정된 데이터 다시 저장
            df.to_csv(file_path, index=False)

            print(f"{csv_file} 수정 완료")

        except Exception as e:
            print(f"{csv_file} 수정 중 오류 발생: {e}")

    print("모든 CSV 파일 수정 완료!")
# Out:
# A.csv 파일 수정 중...
# A.csv 수정 완료
# AAPL.csv 파일 수정 중...
# AAPL.csv 수정 완료
# ABBV.csv 파일 수정 중...
# ABBV.csv 수정 완료
# ABNB.csv 파일 수정 중...
# ABNB.csv 수정 완료
# ABT.csv 파일 수정 중...
# ABT.csv 수정 완료
# ACGL.csv 파일 수정 중...
# ACGL.csv 수정 완료
# ACN.csv 파일 수정 중...
# ACN.csv 수정 완료
# ADBE.csv 파일 수정 중...
# ADBE.csv 수정 완료
# ADI.csv 파일 수정 중...
# ADI.csv 수정 완료
# ADM.csv 파일 수정 중...
# ADM.csv 수정 완료
# ADP.csv 파일 수정 중...
# ADP.csv 수정 완료
# ADSK.csv 파일 수정 중...
# ADSK.csv 수정 완료
# AEE.csv 파일 수정 중...
# AEE.csv 수정 완료
# AEP.csv 파일 수정 중...
# AEP.csv 수정 완료
# AES.csv 파일 수정 중...
# AES.csv 수정 완료
# AFL.csv 파일 수정 중...
# AFL.csv 수정 완료
# AIG.csv 파일 수정 중...
# AIG.csv 수정 완료
# AIZ.csv 파일 수정 중...
# AIZ.csv 수정 완료
# AJG.csv 파일 수정 중...
# AJG.csv 수정 완료
# AKAM.csv 파일 수정 중...
# AKAM.csv 수정 완료
# ALB.csv 파일 수정 중...
# ALB.csv 수정 완료
# ALGN.csv 파일 수정 중...
# ALGN.csv 수정 완료
# ALL.csv 파일 수정 중...
# ALL.csv 수정 완료
# ALLE.csv 파일 수정 중...
# ALLE.csv 수정 완료
# AMAT.csv 파일 수정 중...
# AMAT.csv 수정 완료
# AMCR.csv 파일 수정 중...
# AMCR.csv 수정 완료
# AMD.csv 파일 수정 중...
# AMD.csv 수정 완료
# AME.csv 파일 수정 중...
# AME.csv 수정 완료
# AMGN.csv 파일 수정 중...
# AMGN.csv 수정 완료
# AMP.csv 파일 수정 중...
# AMP.csv 수정 완료
# AMT.csv 파일 수정 중...
# AMT.csv 수정 완료
# AMZN.csv 파일 수정 중...
# AMZN.csv 수정 완료
# ANET.csv 파일 수정 중...
# ANET.csv 수정 완료
# ANSS.csv 파일 수정 중...
# ANSS.csv 수정 완료
# AON.csv 파일 수정 중...
# AON.csv 수정 완료
# AOS.csv 파일 수정 중...
# AOS.csv 수정 완료
# APA.csv 파일 수정 중...
# APA.csv 수정 완료
# APD.csv 파일 수정 중...
# APD.csv 수정 완료
# APH.csv 파일 수정 중...
# APH.csv 수정 완료
# APO.csv 파일 수정 중...
# APO.csv 수정 완료
# APTV.csv 파일 수정 중...
# APTV.csv 수정 완료
# ARE.csv 파일 수정 중...
# ARE.csv 수정 완료
# ATO.csv 파일 수정 중...
# ATO.csv 수정 완료
# AVB.csv 파일 수정 중...
# AVB.csv 수정 완료
# AVGO.csv 파일 수정 중...
# AVGO.csv 수정 완료
# AVY.csv 파일 수정 중...
# AVY.csv 수정 완료
# AWK.csv 파일 수정 중...
# AWK.csv 수정 완료
# AXON.csv 파일 수정 중...
# AXON.csv 수정 완료
# AXP.csv 파일 수정 중...
# AXP.csv 수정 완료
# AZO.csv 파일 수정 중...
# AZO.csv 수정 완료
# BA.csv 파일 수정 중...
# BA.csv 수정 완료
# BAC.csv 파일 수정 중...
# BAC.csv 수정 완료
# BALL.csv 파일 수정 중...
# BALL.csv 수정 완료
# BAX.csv 파일 수정 중...
# BAX.csv 수정 완료
# BBY.csv 파일 수정 중...
# BBY.csv 수정 완료
# BDX.csv 파일 수정 중...
# BDX.csv 수정 완료
# BEN.csv 파일 수정 중...
# BEN.csv 수정 완료
# BF-B.csv 파일 수정 중...
# BF-B.csv 수정 완료
# BG.csv 파일 수정 중...
# BG.csv 수정 완료
# BIIB.csv 파일 수정 중...
# BIIB.csv 수정 완료
# BK.csv 파일 수정 중...
# BK.csv 수정 완료
# BKNG.csv 파일 수정 중...
# BKNG.csv 수정 완료
# BKR.csv 파일 수정 중...
# BKR.csv 수정 완료
# BLDR.csv 파일 수정 중...
# BLDR.csv 수정 완료
# BLK.csv 파일 수정 중...
# BLK.csv 수정 완료
# BMY.csv 파일 수정 중...
# BMY.csv 수정 완료
# BR.csv 파일 수정 중...
# BR.csv 수정 완료
# BRK-B.csv 파일 수정 중...
# BRK-B.csv 수정 완료
# BRO.csv 파일 수정 중...
# BRO.csv 수정 완료
# BSX.csv 파일 수정 중...
# BSX.csv 수정 완료
# BX.csv 파일 수정 중...
# BX.csv 수정 완료
# BXP.csv 파일 수정 중...
# BXP.csv 수정 완료
# C.csv 파일 수정 중...
# C.csv 수정 완료
# CAG.csv 파일 수정 중...
# CAG.csv 수정 완료
# CAH.csv 파일 수정 중...
# CAH.csv 수정 완료
# CARR.csv 파일 수정 중...
# CARR.csv 수정 완료
# CAT.csv 파일 수정 중...
# CAT.csv 수정 완료
# CB.csv 파일 수정 중...
# CB.csv 수정 완료
# CBOE.csv 파일 수정 중...
# CBOE.csv 수정 완료
# CBRE.csv 파일 수정 중...
# CBRE.csv 수정 완료
# CCI.csv 파일 수정 중...
# CCI.csv 수정 완료
# CCL.csv 파일 수정 중...
# CCL.csv 수정 완료
# CDNS.csv 파일 수정 중...
# CDNS.csv 수정 완료
# CDW.csv 파일 수정 중...
# CDW.csv 수정 완료
# CEG.csv 파일 수정 중...
# CEG.csv 수정 완료
# CF.csv 파일 수정 중...
# CF.csv 수정 완료
# CFG.csv 파일 수정 중...
# CFG.csv 수정 완료
# CHD.csv 파일 수정 중...
# CHD.csv 수정 완료
# CHRW.csv 파일 수정 중...
# CHRW.csv 수정 완료
# CHTR.csv 파일 수정 중...
# CHTR.csv 수정 완료
# CI.csv 파일 수정 중...
# CI.csv 수정 완료
# CINF.csv 파일 수정 중...
# CINF.csv 수정 완료
# CL.csv 파일 수정 중...
# CL.csv 수정 완료
# CLX.csv 파일 수정 중...
# CLX.csv 수정 완료
# CMCSA.csv 파일 수정 중...
# CMCSA.csv 수정 완료
# CME.csv 파일 수정 중...
# CME.csv 수정 완료
# CMG.csv 파일 수정 중...
# CMG.csv 수정 완료
# CMI.csv 파일 수정 중...
# CMI.csv 수정 완료
# CMS.csv 파일 수정 중...
# CMS.csv 수정 완료
# CNC.csv 파일 수정 중...
# CNC.csv 수정 완료
# CNP.csv 파일 수정 중...
# CNP.csv 수정 완료
# COF.csv 파일 수정 중...
# COF.csv 수정 완료
# COO.csv 파일 수정 중...
# COO.csv 수정 완료
# COP.csv 파일 수정 중...
# COP.csv 수정 완료
# COR.csv 파일 수정 중...
# COR.csv 수정 완료
# COST.csv 파일 수정 중...
# COST.csv 수정 완료
# CPAY.csv 파일 수정 중...
# CPAY.csv 수정 완료
# CPB.csv 파일 수정 중...
# CPB.csv 수정 완료
# CPRT.csv 파일 수정 중...
# CPRT.csv 수정 완료
# CPT.csv 파일 수정 중...
# CPT.csv 수정 완료
# CRL.csv 파일 수정 중...
# CRL.csv 수정 완료
# CRM.csv 파일 수정 중...
# CRM.csv 수정 완료
# CRWD.csv 파일 수정 중...
# CRWD.csv 수정 완료
# CSCO.csv 파일 수정 중...
# CSCO.csv 수정 완료
# CSGP.csv 파일 수정 중...
# CSGP.csv 수정 완료
# CSX.csv 파일 수정 중...
# CSX.csv 수정 완료
# CTAS.csv 파일 수정 중...
# CTAS.csv 수정 완료
# CTRA.csv 파일 수정 중...
# CTRA.csv 수정 완료
# CTSH.csv 파일 수정 중...
# CTSH.csv 수정 완료
# CTVA.csv 파일 수정 중...
# CTVA.csv 수정 완료
# CVS.csv 파일 수정 중...
# CVS.csv 수정 완료
# CVX.csv 파일 수정 중...
# CVX.csv 수정 완료
# CZR.csv 파일 수정 중...
# CZR.csv 수정 완료
# D.csv 파일 수정 중...
# D.csv 수정 완료
# DAL.csv 파일 수정 중...
# DAL.csv 수정 완료
# DASH.csv 파일 수정 중...
# DASH.csv 수정 완료
# DAY.csv 파일 수정 중...
# DAY.csv 수정 완료
# DD.csv 파일 수정 중...
# DD.csv 수정 완료
# DE.csv 파일 수정 중...
# DE.csv 수정 완료
# DECK.csv 파일 수정 중...
# DECK.csv 수정 완료
# DELL.csv 파일 수정 중...
# DELL.csv 수정 완료
# DFS.csv 파일 수정 중...
# DFS.csv 수정 완료
# DG.csv 파일 수정 중...
# DG.csv 수정 완료
# DGX.csv 파일 수정 중...
# DGX.csv 수정 완료
# DHI.csv 파일 수정 중...
# DHI.csv 수정 완료
# DHR.csv 파일 수정 중...
# DHR.csv 수정 완료
# DIS.csv 파일 수정 중...
# DIS.csv 수정 완료
# DLR.csv 파일 수정 중...
# DLR.csv 수정 완료
# DLTR.csv 파일 수정 중...
# DLTR.csv 수정 완료
# DOC.csv 파일 수정 중...
# DOC.csv 수정 완료
# DOV.csv 파일 수정 중...
# DOV.csv 수정 완료
# DOW.csv 파일 수정 중...
# DOW.csv 수정 완료
# DPZ.csv 파일 수정 중...
# DPZ.csv 수정 완료
# DRI.csv 파일 수정 중...
# DRI.csv 수정 완료
# DTE.csv 파일 수정 중...
# DTE.csv 수정 완료
# DUK.csv 파일 수정 중...
# DUK.csv 수정 완료
# DVA.csv 파일 수정 중...
# DVA.csv 수정 완료
# DVN.csv 파일 수정 중...
# DVN.csv 수정 완료
# DXCM.csv 파일 수정 중...
# DXCM.csv 수정 완료
# EA.csv 파일 수정 중...
# EA.csv 수정 완료
# EBAY.csv 파일 수정 중...
# EBAY.csv 수정 완료
# ECL.csv 파일 수정 중...
# ECL.csv 수정 완료
# ED.csv 파일 수정 중...
# ED.csv 수정 완료
# EFX.csv 파일 수정 중...
# EFX.csv 수정 완료
# EG.csv 파일 수정 중...
# EG.csv 수정 완료
# EIX.csv 파일 수정 중...
# EIX.csv 수정 완료
# EL.csv 파일 수정 중...
# EL.csv 수정 완료
# ELV.csv 파일 수정 중...
# ELV.csv 수정 완료
# EMN.csv 파일 수정 중...
# EMN.csv 수정 완료
# EMR.csv 파일 수정 중...
# EMR.csv 수정 완료
# ENPH.csv 파일 수정 중...
# ENPH.csv 수정 완료
# EOG.csv 파일 수정 중...
# EOG.csv 수정 완료
# EPAM.csv 파일 수정 중...
# EPAM.csv 수정 완료
# EQIX.csv 파일 수정 중...
# EQIX.csv 수정 완료
# EQR.csv 파일 수정 중...
# EQR.csv 수정 완료
# EQT.csv 파일 수정 중...
# EQT.csv 수정 완료
# ERIE.csv 파일 수정 중...
# ERIE.csv 수정 완료
# ES.csv 파일 수정 중...
# ES.csv 수정 완료
# ESS.csv 파일 수정 중...
# ESS.csv 수정 완료
# ETN.csv 파일 수정 중...
# ETN.csv 수정 완료
# ETR.csv 파일 수정 중...
# ETR.csv 수정 완료
# EVRG.csv 파일 수정 중...
# EVRG.csv 수정 완료
# EW.csv 파일 수정 중...
# EW.csv 수정 완료
# EXC.csv 파일 수정 중...
# EXC.csv 수정 완료
# EXE.csv 파일 수정 중...
# EXE.csv 수정 완료
# EXPD.csv 파일 수정 중...
# EXPD.csv 수정 완료
# EXPE.csv 파일 수정 중...
# EXPE.csv 수정 완료
# EXR.csv 파일 수정 중...
# EXR.csv 수정 완료
# F.csv 파일 수정 중...
# F.csv 수정 완료
# FANG.csv 파일 수정 중...
# FANG.csv 수정 완료
# FAST.csv 파일 수정 중...
# FAST.csv 수정 완료
# FCX.csv 파일 수정 중...
# FCX.csv 수정 완료
# FDS.csv 파일 수정 중...
# FDS.csv 수정 완료
# FDX.csv 파일 수정 중...
# FDX.csv 수정 완료
# FE.csv 파일 수정 중...
# FE.csv 수정 완료
# FFIV.csv 파일 수정 중...
# FFIV.csv 수정 완료
# FI.csv 파일 수정 중...
# FI.csv 수정 완료
# FICO.csv 파일 수정 중...
# FICO.csv 수정 완료
# FIS.csv 파일 수정 중...
# FIS.csv 수정 완료
# FITB.csv 파일 수정 중...
# FITB.csv 수정 완료
# FOX.csv 파일 수정 중...
# FOX.csv 수정 완료
# FOXA.csv 파일 수정 중...
# FOXA.csv 수정 완료
# FRT.csv 파일 수정 중...
# FRT.csv 수정 완료
# FSLR.csv 파일 수정 중...
# FSLR.csv 수정 완료
# FTNT.csv 파일 수정 중...
# FTNT.csv 수정 완료
# FTV.csv 파일 수정 중...
# FTV.csv 수정 완료
# GD.csv 파일 수정 중...
# GD.csv 수정 완료
# GDDY.csv 파일 수정 중...
# GDDY.csv 수정 완료
# GE.csv 파일 수정 중...
# GE.csv 수정 완료
# GEHC.csv 파일 수정 중...
# GEHC.csv 수정 완료
# GEN.csv 파일 수정 중...
# GEN.csv 수정 완료
# GEV.csv 파일 수정 중...
# GEV.csv 수정 완료
# GILD.csv 파일 수정 중...
# GILD.csv 수정 완료
# GIS.csv 파일 수정 중...
# GIS.csv 수정 완료
# GL.csv 파일 수정 중...
# GL.csv 수정 완료
# GLW.csv 파일 수정 중...
# GLW.csv 수정 완료
# GM.csv 파일 수정 중...
# GM.csv 수정 완료
# GNRC.csv 파일 수정 중...
# GNRC.csv 수정 완료
# GOOG.csv 파일 수정 중...
# GOOG.csv 수정 완료
# GOOGL.csv 파일 수정 중...
# GOOGL.csv 수정 완료
# GPC.csv 파일 수정 중...
# GPC.csv 수정 완료
# GPN.csv 파일 수정 중...
# GPN.csv 수정 완료
# GRMN.csv 파일 수정 중...
# GRMN.csv 수정 완료
# GS.csv 파일 수정 중...
# GS.csv 수정 완료
# GWW.csv 파일 수정 중...
# GWW.csv 수정 완료
# HAL.csv 파일 수정 중...
# HAL.csv 수정 완료
# HAS.csv 파일 수정 중...
# HAS.csv 수정 완료
# HBAN.csv 파일 수정 중...
# HBAN.csv 수정 완료
# HCA.csv 파일 수정 중...
# HCA.csv 수정 완료
# HD.csv 파일 수정 중...
# HD.csv 수정 완료
# HES.csv 파일 수정 중...
# HES.csv 수정 완료
# HIG.csv 파일 수정 중...
# HIG.csv 수정 완료
# HII.csv 파일 수정 중...
# HII.csv 수정 완료
# HLT.csv 파일 수정 중...
# HLT.csv 수정 완료
# HOLX.csv 파일 수정 중...
# HOLX.csv 수정 완료
# HON.csv 파일 수정 중...
# HON.csv 수정 완료
# HPE.csv 파일 수정 중...
# HPE.csv 수정 완료
# HPQ.csv 파일 수정 중...
# HPQ.csv 수정 완료
# HRL.csv 파일 수정 중...
# HRL.csv 수정 완료
# HSIC.csv 파일 수정 중...
# HSIC.csv 수정 완료
# HST.csv 파일 수정 중...
# HST.csv 수정 완료
# HSY.csv 파일 수정 중...
# HSY.csv 수정 완료
# HUBB.csv 파일 수정 중...
# HUBB.csv 수정 완료
# HUM.csv 파일 수정 중...
# HUM.csv 수정 완료
# HWM.csv 파일 수정 중...
# HWM.csv 수정 완료
# IBM.csv 파일 수정 중...
# IBM.csv 수정 완료
# ICE.csv 파일 수정 중...
# ICE.csv 수정 완료
# IDXX.csv 파일 수정 중...
# IDXX.csv 수정 완료
# IEX.csv 파일 수정 중...
# IEX.csv 수정 완료
# IFF.csv 파일 수정 중...
# IFF.csv 수정 완료
# INCY.csv 파일 수정 중...
# INCY.csv 수정 완료
# INTC.csv 파일 수정 중...
# INTC.csv 수정 완료
# INTU.csv 파일 수정 중...
# INTU.csv 수정 완료
# INVH.csv 파일 수정 중...
# INVH.csv 수정 완료
# IP.csv 파일 수정 중...
# IP.csv 수정 완료
# IPG.csv 파일 수정 중...
# IPG.csv 수정 완료
# IQV.csv 파일 수정 중...
# IQV.csv 수정 완료
# IR.csv 파일 수정 중...
# IR.csv 수정 완료
# IRM.csv 파일 수정 중...
# IRM.csv 수정 완료
# ISRG.csv 파일 수정 중...
# ISRG.csv 수정 완료
# IT.csv 파일 수정 중...
# IT.csv 수정 완료
# ITW.csv 파일 수정 중...
# ITW.csv 수정 완료
# IVZ.csv 파일 수정 중...
# IVZ.csv 수정 완료
# J.csv 파일 수정 중...
# J.csv 수정 완료
# JBHT.csv 파일 수정 중...
# JBHT.csv 수정 완료
# JBL.csv 파일 수정 중...
# JBL.csv 수정 완료
# JCI.csv 파일 수정 중...
# JCI.csv 수정 완료
# JKHY.csv 파일 수정 중...
# JKHY.csv 수정 완료
# JNJ.csv 파일 수정 중...
# JNJ.csv 수정 완료
# JNPR.csv 파일 수정 중...
# JNPR.csv 수정 완료
# JPM.csv 파일 수정 중...
# JPM.csv 수정 완료
# K.csv 파일 수정 중...
# K.csv 수정 완료
# KDP.csv 파일 수정 중...
# KDP.csv 수정 완료
# KEY.csv 파일 수정 중...
# KEY.csv 수정 완료
# KEYS.csv 파일 수정 중...
# KEYS.csv 수정 완료
# KHC.csv 파일 수정 중...
# KHC.csv 수정 완료
# KIM.csv 파일 수정 중...
# KIM.csv 수정 완료
# KKR.csv 파일 수정 중...
# KKR.csv 수정 완료
# KLAC.csv 파일 수정 중...
# KLAC.csv 수정 완료
# KMB.csv 파일 수정 중...
# KMB.csv 수정 완료
# KMI.csv 파일 수정 중...
# KMI.csv 수정 완료
# KMX.csv 파일 수정 중...
# KMX.csv 수정 완료
# KO.csv 파일 수정 중...
# KO.csv 수정 완료
# KR.csv 파일 수정 중...
# KR.csv 수정 완료
# KVUE.csv 파일 수정 중...
# KVUE.csv 수정 완료
# L.csv 파일 수정 중...
# L.csv 수정 완료
# LDOS.csv 파일 수정 중...
# LDOS.csv 수정 완료
# LEN.csv 파일 수정 중...
# LEN.csv 수정 완료
# LH.csv 파일 수정 중...
# LH.csv 수정 완료
# LHX.csv 파일 수정 중...
# LHX.csv 수정 완료
# LII.csv 파일 수정 중...
# LII.csv 수정 완료
# LIN.csv 파일 수정 중...
# LIN.csv 수정 완료
# LKQ.csv 파일 수정 중...
# LKQ.csv 수정 완료
# LLY.csv 파일 수정 중...
# LLY.csv 수정 완료
# LMT.csv 파일 수정 중...
# LMT.csv 수정 완료
# LNT.csv 파일 수정 중...
# LNT.csv 수정 완료
# LOW.csv 파일 수정 중...
# LOW.csv 수정 완료
# LRCX.csv 파일 수정 중...
# LRCX.csv 수정 완료
# LULU.csv 파일 수정 중...
# LULU.csv 수정 완료
# LUV.csv 파일 수정 중...
# LUV.csv 수정 완료
# LVS.csv 파일 수정 중...
# LVS.csv 수정 완료
# LW.csv 파일 수정 중...
# LW.csv 수정 완료
# LYB.csv 파일 수정 중...
# LYB.csv 수정 완료
# LYV.csv 파일 수정 중...
# LYV.csv 수정 완료
# MA.csv 파일 수정 중...
# MA.csv 수정 완료
# MAA.csv 파일 수정 중...
# MAA.csv 수정 완료
# MAR.csv 파일 수정 중...
# MAR.csv 수정 완료
# MAS.csv 파일 수정 중...
# MAS.csv 수정 완료
# MCD.csv 파일 수정 중...
# MCD.csv 수정 완료
# MCHP.csv 파일 수정 중...
# MCHP.csv 수정 완료
# MCK.csv 파일 수정 중...
# MCK.csv 수정 완료
# MCO.csv 파일 수정 중...
# MCO.csv 수정 완료
# MDLZ.csv 파일 수정 중...
# MDLZ.csv 수정 완료
# MDT.csv 파일 수정 중...
# MDT.csv 수정 완료
# MET.csv 파일 수정 중...
# MET.csv 수정 완료
# META.csv 파일 수정 중...
# META.csv 수정 완료
# MGM.csv 파일 수정 중...
# MGM.csv 수정 완료
# MHK.csv 파일 수정 중...
# MHK.csv 수정 완료
# MKC.csv 파일 수정 중...
# MKC.csv 수정 완료
# MKTX.csv 파일 수정 중...
# MKTX.csv 수정 완료
# MLM.csv 파일 수정 중...
# MLM.csv 수정 완료
# MMC.csv 파일 수정 중...
# MMC.csv 수정 완료
# MMM.csv 파일 수정 중...
# MMM.csv 수정 완료
# MNST.csv 파일 수정 중...
# MNST.csv 수정 완료
# MO.csv 파일 수정 중...
# MO.csv 수정 완료
# MOH.csv 파일 수정 중...
# MOH.csv 수정 완료
# MOS.csv 파일 수정 중...
# MOS.csv 수정 완료
# MPC.csv 파일 수정 중...
# MPC.csv 수정 완료
# MPWR.csv 파일 수정 중...
# MPWR.csv 수정 완료
# MRK.csv 파일 수정 중...
# MRK.csv 수정 완료
# MRNA.csv 파일 수정 중...
# MRNA.csv 수정 완료
# MS.csv 파일 수정 중...
# MS.csv 수정 완료
# MSCI.csv 파일 수정 중...
# MSCI.csv 수정 완료
# MSFT.csv 파일 수정 중...
# MSFT.csv 수정 완료
# MSI.csv 파일 수정 중...
# MSI.csv 수정 완료
# MTB.csv 파일 수정 중...
# MTB.csv 수정 완료
# MTCH.csv 파일 수정 중...
# MTCH.csv 수정 완료
# MTD.csv 파일 수정 중...
# MTD.csv 수정 완료
# MU.csv 파일 수정 중...
# MU.csv 수정 완료
# NCLH.csv 파일 수정 중...
# NCLH.csv 수정 완료
# NDAQ.csv 파일 수정 중...
# NDAQ.csv 수정 완료
# NDSN.csv 파일 수정 중...
# NDSN.csv 수정 완료
# NEE.csv 파일 수정 중...
# NEE.csv 수정 완료
# NEM.csv 파일 수정 중...
# NEM.csv 수정 완료
# NFLX.csv 파일 수정 중...
# NFLX.csv 수정 완료
# NI.csv 파일 수정 중...
# NI.csv 수정 완료
# NKE.csv 파일 수정 중...
# NKE.csv 수정 완료
# NOC.csv 파일 수정 중...
# NOC.csv 수정 완료
# NOW.csv 파일 수정 중...
# NOW.csv 수정 완료
# NRG.csv 파일 수정 중...
# NRG.csv 수정 완료
# NSC.csv 파일 수정 중...
# NSC.csv 수정 완료
# NTAP.csv 파일 수정 중...
# NTAP.csv 수정 완료
# NTRS.csv 파일 수정 중...
# NTRS.csv 수정 완료
# NUE.csv 파일 수정 중...
# NUE.csv 수정 완료
# NVDA.csv 파일 수정 중...
# NVDA.csv 수정 완료
# NVR.csv 파일 수정 중...
# NVR.csv 수정 완료
# NWS.csv 파일 수정 중...
# NWS.csv 수정 완료
# NWSA.csv 파일 수정 중...
# NWSA.csv 수정 완료
# NXPI.csv 파일 수정 중...
# NXPI.csv 수정 완료
# O.csv 파일 수정 중...
# O.csv 수정 완료
# ODFL.csv 파일 수정 중...
# ODFL.csv 수정 완료
# OKE.csv 파일 수정 중...
# OKE.csv 수정 완료
# OMC.csv 파일 수정 중...
# OMC.csv 수정 완료
# ON.csv 파일 수정 중...
# ON.csv 수정 완료
# ORCL.csv 파일 수정 중...
# ORCL.csv 수정 완료
# ORLY.csv 파일 수정 중...
# ORLY.csv 수정 완료
# OTIS.csv 파일 수정 중...
# OTIS.csv 수정 완료
# OXY.csv 파일 수정 중...
# OXY.csv 수정 완료
# PANW.csv 파일 수정 중...
# PANW.csv 수정 완료
# PARA.csv 파일 수정 중...
# PARA.csv 수정 완료
# PAYC.csv 파일 수정 중...
# PAYC.csv 수정 완료
# PAYX.csv 파일 수정 중...
# PAYX.csv 수정 완료
# PCAR.csv 파일 수정 중...
# PCAR.csv 수정 완료
# PCG.csv 파일 수정 중...
# PCG.csv 수정 완료
# PEG.csv 파일 수정 중...
# PEG.csv 수정 완료
# PEP.csv 파일 수정 중...
# PEP.csv 수정 완료
# PFE.csv 파일 수정 중...
# PFE.csv 수정 완료
# PFG.csv 파일 수정 중...
# PFG.csv 수정 완료
# PG.csv 파일 수정 중...
# PG.csv 수정 완료
# PGR.csv 파일 수정 중...
# PGR.csv 수정 완료
# PH.csv 파일 수정 중...
# PH.csv 수정 완료
# PHM.csv 파일 수정 중...
# PHM.csv 수정 완료
# PKG.csv 파일 수정 중...
# PKG.csv 수정 완료
# PLD.csv 파일 수정 중...
# PLD.csv 수정 완료
# PLTR.csv 파일 수정 중...
# PLTR.csv 수정 완료
# PM.csv 파일 수정 중...
# PM.csv 수정 완료
# PNC.csv 파일 수정 중...
# PNC.csv 수정 완료
# PNR.csv 파일 수정 중...
# PNR.csv 수정 완료
# PNW.csv 파일 수정 중...
# PNW.csv 수정 완료
# PODD.csv 파일 수정 중...
# PODD.csv 수정 완료
# POOL.csv 파일 수정 중...
# POOL.csv 수정 완료
# PPG.csv 파일 수정 중...
# PPG.csv 수정 완료
# PPL.csv 파일 수정 중...
# PPL.csv 수정 완료
# PRU.csv 파일 수정 중...
# PRU.csv 수정 완료
# PSA.csv 파일 수정 중...
# PSA.csv 수정 완료
# PSX.csv 파일 수정 중...
# PSX.csv 수정 완료
# PTC.csv 파일 수정 중...
# PTC.csv 수정 완료
# PWR.csv 파일 수정 중...
# PWR.csv 수정 완료
# PYPL.csv 파일 수정 중...
# PYPL.csv 수정 완료
# QCOM.csv 파일 수정 중...
# QCOM.csv 수정 완료
# RCL.csv 파일 수정 중...
# RCL.csv 수정 완료
# REG.csv 파일 수정 중...
# REG.csv 수정 완료
# REGN.csv 파일 수정 중...
# REGN.csv 수정 완료
# RF.csv 파일 수정 중...
# RF.csv 수정 완료
# RJF.csv 파일 수정 중...
# RJF.csv 수정 완료
# RL.csv 파일 수정 중...
# RL.csv 수정 완료
# RMD.csv 파일 수정 중...
# RMD.csv 수정 완료
# ROK.csv 파일 수정 중...
# ROK.csv 수정 완료
# ROL.csv 파일 수정 중...
# ROL.csv 수정 완료
# ROP.csv 파일 수정 중...
# ROP.csv 수정 완료
# ROST.csv 파일 수정 중...
# ROST.csv 수정 완료
# RSG.csv 파일 수정 중...
# RSG.csv 수정 완료
# RTX.csv 파일 수정 중...
# RTX.csv 수정 완료
# RVTY.csv 파일 수정 중...
# RVTY.csv 수정 완료
# SBAC.csv 파일 수정 중...
# SBAC.csv 수정 완료
# SBUX.csv 파일 수정 중...
# SBUX.csv 수정 완료
# SCHW.csv 파일 수정 중...
# SCHW.csv 수정 완료
# SHW.csv 파일 수정 중...
# SHW.csv 수정 완료
# SJM.csv 파일 수정 중...
# SJM.csv 수정 완료
# SLB.csv 파일 수정 중...
# SLB.csv 수정 완료
# SMCI.csv 파일 수정 중...
# SMCI.csv 수정 완료
# SNA.csv 파일 수정 중...
# SNA.csv 수정 완료
# SNPS.csv 파일 수정 중...
# SNPS.csv 수정 완료
# SO.csv 파일 수정 중...
# SO.csv 수정 완료
# SOLV.csv 파일 수정 중...
# SOLV.csv 수정 완료
# SPG.csv 파일 수정 중...
# SPG.csv 수정 완료
# SPGI.csv 파일 수정 중...
# SPGI.csv 수정 완료
# SRE.csv 파일 수정 중...
# SRE.csv 수정 완료
# STE.csv 파일 수정 중...
# STE.csv 수정 완료
# STLD.csv 파일 수정 중...
# STLD.csv 수정 완료
# STT.csv 파일 수정 중...
# STT.csv 수정 완료
# STX.csv 파일 수정 중...
# STX.csv 수정 완료
# STZ.csv 파일 수정 중...
# STZ.csv 수정 완료
# SW.csv 파일 수정 중...
# SW.csv 수정 완료
# SWK.csv 파일 수정 중...
# SWK.csv 수정 완료
# SWKS.csv 파일 수정 중...
# SWKS.csv 수정 완료
# SYF.csv 파일 수정 중...
# SYF.csv 수정 완료
# SYK.csv 파일 수정 중...
# SYK.csv 수정 완료
# SYY.csv 파일 수정 중...
# SYY.csv 수정 완료
# T.csv 파일 수정 중...
# T.csv 수정 완료
# TAP.csv 파일 수정 중...
# TAP.csv 수정 완료
# TDG.csv 파일 수정 중...
# TDG.csv 수정 완료
# TDY.csv 파일 수정 중...
# TDY.csv 수정 완료
# TECH.csv 파일 수정 중...
# TECH.csv 수정 완료
# TEL.csv 파일 수정 중...
# TEL.csv 수정 완료
# TER.csv 파일 수정 중...
# TER.csv 수정 완료
# TFC.csv 파일 수정 중...
# TFC.csv 수정 완료
# TGT.csv 파일 수정 중...
# TGT.csv 수정 완료
# TJX.csv 파일 수정 중...
# TJX.csv 수정 완료
# TKO.csv 파일 수정 중...
# TKO.csv 수정 완료
# TMO.csv 파일 수정 중...
# TMO.csv 수정 완료
# TMUS.csv 파일 수정 중...
# TMUS.csv 수정 완료
# TPL.csv 파일 수정 중...
# TPL.csv 수정 완료
# TPR.csv 파일 수정 중...
# TPR.csv 수정 완료
# TRGP.csv 파일 수정 중...
# TRGP.csv 수정 완료
# TRMB.csv 파일 수정 중...
# TRMB.csv 수정 완료
# TROW.csv 파일 수정 중...
# TROW.csv 수정 완료
# TRV.csv 파일 수정 중...
# TRV.csv 수정 완료
# TSCO.csv 파일 수정 중...
# TSCO.csv 수정 완료
# TSLA.csv 파일 수정 중...
# TSLA.csv 수정 완료
# TSN.csv 파일 수정 중...
# TSN.csv 수정 완료
# TT.csv 파일 수정 중...
# TT.csv 수정 완료
# TTWO.csv 파일 수정 중...
# TTWO.csv 수정 완료
# TXN.csv 파일 수정 중...
# TXN.csv 수정 완료
# TXT.csv 파일 수정 중...
# TXT.csv 수정 완료
# TYL.csv 파일 수정 중...
# TYL.csv 수정 완료
# UAL.csv 파일 수정 중...
# UAL.csv 수정 완료
# UBER.csv 파일 수정 중...
# UBER.csv 수정 완료
# UDR.csv 파일 수정 중...
# UDR.csv 수정 완료
# UHS.csv 파일 수정 중...
# UHS.csv 수정 완료
# ULTA.csv 파일 수정 중...
# ULTA.csv 수정 완료
# UNH.csv 파일 수정 중...
# UNH.csv 수정 완료
# UNP.csv 파일 수정 중...
# UNP.csv 수정 완료
# UPS.csv 파일 수정 중...
# UPS.csv 수정 완료
# URI.csv 파일 수정 중...
# URI.csv 수정 완료
# USB.csv 파일 수정 중...
# USB.csv 수정 완료
# V.csv 파일 수정 중...
# V.csv 수정 완료
# VICI.csv 파일 수정 중...
# VICI.csv 수정 완료
# VLO.csv 파일 수정 중...
# VLO.csv 수정 완료
# VLTO.csv 파일 수정 중...
# VLTO.csv 수정 완료
# VMC.csv 파일 수정 중...
# VMC.csv 수정 완료
# VRSK.csv 파일 수정 중...
# VRSK.csv 수정 완료
# VRSN.csv 파일 수정 중...
# VRSN.csv 수정 완료
# VRTX.csv 파일 수정 중...
# VRTX.csv 수정 완료
# VST.csv 파일 수정 중...
# VST.csv 수정 완료
# VTR.csv 파일 수정 중...
# VTR.csv 수정 완료
# VTRS.csv 파일 수정 중...
# VTRS.csv 수정 완료
# VZ.csv 파일 수정 중...
# VZ.csv 수정 완료
# WAB.csv 파일 수정 중...
# WAB.csv 수정 완료
# WAT.csv 파일 수정 중...
# WAT.csv 수정 완료
# WBA.csv 파일 수정 중...
# WBA.csv 수정 완료
# WBD.csv 파일 수정 중...
# WBD.csv 수정 완료
# WDAY.csv 파일 수정 중...
# WDAY.csv 수정 완료
# WDC.csv 파일 수정 중...
# WDC.csv 수정 완료
# WEC.csv 파일 수정 중...
# WEC.csv 수정 완료
# WELL.csv 파일 수정 중...
# WELL.csv 수정 완료
# WFC.csv 파일 수정 중...
# WFC.csv 수정 완료
# WM.csv 파일 수정 중...
# WM.csv 수정 완료
# WMB.csv 파일 수정 중...
# WMB.csv 수정 완료
# WMT.csv 파일 수정 중...
# WMT.csv 수정 완료
# WRB.csv 파일 수정 중...
# WRB.csv 수정 완료
# WSM.csv 파일 수정 중...
# WSM.csv 수정 완료
# WST.csv 파일 수정 중...
# WST.csv 수정 완료
# WTW.csv 파일 수정 중...
# WTW.csv 수정 완료
# WY.csv 파일 수정 중...
# WY.csv 수정 완료
# WYNN.csv 파일 수정 중...
# WYNN.csv 수정 완료
# XEL.csv 파일 수정 중...
# XEL.csv 수정 완료
# XOM.csv 파일 수정 중...
# XOM.csv 수정 완료
# XYL.csv 파일 수정 중...
# XYL.csv 수정 완료
# YUM.csv 파일 수정 중...
# YUM.csv 수정 완료
# ZBH.csv 파일 수정 중...
# ZBH.csv 수정 완료
# ZBRA.csv 파일 수정 중...
# ZBRA.csv 수정 완료
# ZTS.csv 파일 수정 중...
# ZTS.csv 수정 완료
# 모든 CSV 파일 수정 완료!

# %%
# 테스트용 상승패턴 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 저장할 디렉토리 설정 (상승 패턴 이미지 저장)
output_dir = "./data/price_2to3percent_surge_patterns_test"
os.makedirs(output_dir, exist_ok=True)

# 저장된 CSV 파일 경로 (S&P 500 주식 데이터 폴더)
data_dir = "./data/sp500_stocks_test/"

# 저장된 이미지 개수 제한
MAX_IMAGES = 100000000
saved_image_count = 0

# 봉 개수 설정 (전날 대비 2~3% 이상 오른 날 기준으로 과거 20일)
N_CANDLES = 20

# 기존 저장된 이미지 확인 (중복 방지)
existing_images = set(os.listdir(output_dir))

# 모든 CSV 파일 가져오기 (S&P 500 종목 전체 대상)
csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# 모든 CSV 파일에 대해 데이터 분석
for csv_file in csv_files:
    if saved_image_count >= MAX_IMAGES:
        print("최대 저장 개수(100000000장) 도달, 저장 중단")
        break

    ticker = csv_file.replace(".csv", "")  # 종목명 추출
    file_path = os.path.join(data_dir, csv_file)

    print(f"{ticker} 데이터 로드 중...")
    df = pd.read_csv(file_path)

    # 날짜 변환 및 인덱스 설정
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

    # 전날 대비 5% 이상 상승한 날 찾기
    df['pct_change'] = df['Open'].pct_change() * 100  # 퍼센트 변환
    surge_days = df[(df['pct_change'] >= 2)&(df['pct_change'] < 3)].index  # 2~3% 상승한 날짜 리스트

    # 상승한 날 기준으로 과거 20일의 봉차트 저장
    for surge_date in surge_days:
        if saved_image_count >= MAX_IMAGES:
            print("최대 저장 개수(100000000장) 도달, 저장 중단")
            break

        # 파일명 설정
        file_name = f"{ticker}_{surge_date.strftime('%Y-%m-%d')}.png"
        file_path = os.path.join(output_dir, file_name)

        # 중복 확인: 파일이 이미 존재하면 건너뛰기
        if file_name in existing_images:
            print(f"이미 존재하는 파일: {file_name}, 건너뜀.")
            continue

        # 해당 날짜 기준으로 과거 20일 데이터 가져오기
        end_idx = df.index.get_loc(surge_date)
        start_idx = max(end_idx - N_CANDLES, 0)  # 최소 20개 봉이 있어야 함

        if start_idx == 0:
            continue  # 데이터가 부족하면 스킵

        df_fixed = df.iloc[start_idx:end_idx]

        # 캔들스틱 차트 스타일 지정
        mc = mpf.make_marketcolors(up='g', down='r', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # 캔들스틱 차트 저장
        mpf.plot(
            df_fixed,
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=file_path
        )

        # 이미지 크기 조정 (CNN 학습용 224x224 픽셀)
        img = Image.open(file_path)
        img = img.resize((224, 224))
        img.save(file_path)

        saved_image_count += 1
        existing_images.add(file_name)  # 새로 생성된 파일 추가

print(f"총 {saved_image_count}장의 상승 패턴 이미지 저장 완료!")
# Out:
# A 데이터 로드 중...
# 이미 존재하는 파일: A_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: A_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: A_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: A_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: A_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: A_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: A_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: A_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: A_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: A_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: A_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: A_2025-03-06.png, 건너뜀.
# 이미 존재하는 파일: A_2025-03-24.png, 건너뜀.
# AAPL 데이터 로드 중...
# 이미 존재하는 파일: AAPL_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-03-03.png, 건너뜀.
# ABBV 데이터 로드 중...
# 이미 존재하는 파일: ABBV_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-03-06.png, 건너뜀.
# ABNB 데이터 로드 중...
# 이미 존재하는 파일: ABNB_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2025-01-29.png, 건너뜀.
# ABT 데이터 로드 중...
# 이미 존재하는 파일: ABT_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: ABT_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: ABT_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ABT_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: ABT_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: ABT_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: ABT_2025-03-04.png, 건너뜀.
# ACGL 데이터 로드 중...
# 이미 존재하는 파일: ACGL_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-12-24.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2025-01-17.png, 건너뜀.
# ACN 데이터 로드 중...
# 이미 존재하는 파일: ACN_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ACN_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: ACN_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: ACN_2025-02-05.png, 건너뜀.
# ADBE 데이터 로드 중...
# 이미 존재하는 파일: ADBE_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2025-03-24.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2025-03-26.png, 건너뜀.
# ADI 데이터 로드 중...
# 이미 존재하는 파일: ADI_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-08-21.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-03-03.png, 건너뜀.
# ADM 데이터 로드 중...
# 이미 존재하는 파일: ADM_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-05-17.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-01-02.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-03-27.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-03-28.png, 건너뜀.
# ADP 데이터 로드 중...
# 이미 존재하는 파일: ADP_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: ADP_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: ADP_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: ADP_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ADP_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: ADP_2025-03-04.png, 건너뜀.
# ADSK 데이터 로드 중...
# 이미 존재하는 파일: ADSK_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-03-18.png, 건너뜀.
# AEE 데이터 로드 중...
# 이미 존재하는 파일: AEE_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: AEE_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: AEE_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: AEE_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: AEE_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: AEE_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: AEE_2025-03-04.png, 건너뜀.
# AEP 데이터 로드 중...
# 이미 존재하는 파일: AEP_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: AEP_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: AEP_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: AEP_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: AEP_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: AEP_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-03-31.png, 건너뜀.
# AES 데이터 로드 중...
# 이미 존재하는 파일: AES_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-11-29.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-01-02.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-03-10.png, 건너뜀.
# AFL 데이터 로드 중...
# 이미 존재하는 파일: AFL_2024-04-15.png, 건너뜀.
# 이미 존재하는 파일: AFL_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: AFL_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: AFL_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: AFL_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: AFL_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: AFL_2025-02-25.png, 건너뜀.
# AIG 데이터 로드 중...
# 이미 존재하는 파일: AIG_2024-05-20.png, 건너뜀.
# 이미 존재하는 파일: AIG_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: AIG_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: AIG_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: AIG_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: AIG_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: AIG_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: AIG_2025-02-25.png, 건너뜀.
# AIZ 데이터 로드 중...
# 이미 존재하는 파일: AIZ_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2025-03-17.png, 건너뜀.
# AJG 데이터 로드 중...
# 이미 존재하는 파일: AJG_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: AJG_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: AJG_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: AJG_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: AJG_2025-03-04.png, 건너뜀.
# AKAM 데이터 로드 중...
# 이미 존재하는 파일: AKAM_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2025-03-03.png, 건너뜀.
# ALB 데이터 로드 중...
# 이미 존재하는 파일: ALB_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-22.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-03-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-03-17.png, 건너뜀.
# ALGN 데이터 로드 중...
# 이미 존재하는 파일: ALGN_2024-04-08.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-08-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-03-12.png, 건너뜀.
# ALL 데이터 로드 중...
# 이미 존재하는 파일: ALL_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: ALL_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: ALL_2025-01-28.png, 건너뜀.
# ALLE 데이터 로드 중...
# 이미 존재하는 파일: ALLE_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-03-14.png, 건너뜀.
# AMAT 데이터 로드 중...
# 이미 존재하는 파일: AMAT_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-03-14.png, 건너뜀.
# AMCR 데이터 로드 중...
# 이미 존재하는 파일: AMCR_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2025-03-27.png, 건너뜀.
# AMD 데이터 로드 중...
# 이미 존재하는 파일: AMD_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-03-17.png, 건너뜀.
# AME 데이터 로드 중...
# 이미 존재하는 파일: AME_2024-04-15.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: AME_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: AME_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: AME_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: AME_2025-02-20.png, 건너뜀.
# AMGN 데이터 로드 중...
# 이미 존재하는 파일: AMGN_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-03-04.png, 건너뜀.
# AMP 데이터 로드 중...
# 이미 존재하는 파일: AMP_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-03-24.png, 건너뜀.
# AMT 데이터 로드 중...
# 이미 존재하는 파일: AMT_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-05-17.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-07-30.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: AMT_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: AMT_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: AMT_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: AMT_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: AMT_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: AMT_2025-03-28.png, 건너뜀.
# AMZN 데이터 로드 중...
# 이미 존재하는 파일: AMZN_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-04-08.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-04-11.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-12-02.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-03-05.png, 건너뜀.
# ANET 데이터 로드 중...
# 이미 존재하는 파일: ANET_2024-04-08.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-07-05.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-10-01.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-14.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-25.png, 건너뜀.
# ANSS 데이터 로드 중...
# 이미 존재하는 파일: ANSS_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2025-03-24.png, 건너뜀.
# AON 데이터 로드 중...
# 이미 존재하는 파일: AON_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: AON_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: AON_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: AON_2025-01-27.png, 건너뜀.
# AOS 데이터 로드 중...
# 이미 존재하는 파일: AOS_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AOS_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: AOS_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: AOS_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: AOS_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: AOS_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: AOS_2025-03-10.png, 건너뜀.
# APA 데이터 로드 중...
# 이미 존재하는 파일: APA_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-04-11.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-03-18.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-03-20.png, 건너뜀.
# APD 데이터 로드 중...
# 이미 존재하는 파일: APD_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-05-17.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: APD_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: APD_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: APD_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: APD_2025-02-26.png, 건너뜀.
# APH 데이터 로드 중...
# 이미 존재하는 파일: APH_2024-04-08.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-03-03.png, 건너뜀.
# APO 데이터 로드 중...
# 이미 존재하는 파일: APO_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-03-20.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-03-24.png, 건너뜀.
# APTV 데이터 로드 중...
# 이미 존재하는 파일: APTV_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-12-18.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-03-24.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-03-25.png, 건너뜀.
# ARE 데이터 로드 중...
# 이미 존재하는 파일: ARE_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: ARE_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: ARE_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: ARE_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: ARE_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: ARE_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: ARE_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: ARE_2025-03-10.png, 건너뜀.
# ATO 데이터 로드 중...
# 이미 존재하는 파일: ATO_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: ATO_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: ATO_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: ATO_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ATO_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: ATO_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: ATO_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: ATO_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: ATO_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: ATO_2025-03-17.png, 건너뜀.
# AVB 데이터 로드 중...
# 이미 존재하는 파일: AVB_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: AVB_2025-01-14.png, 건너뜀.
# AVGO 데이터 로드 중...
# 이미 존재하는 파일: AVGO_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-08-12.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-12-02.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-12-27.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-02-13.png, 건너뜀.
# AVY 데이터 로드 중...
# 이미 존재하는 파일: AVY_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: AVY_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: AVY_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: AVY_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AVY_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: AVY_2025-01-14.png, 건너뜀.
# AWK 데이터 로드 중...
# 이미 존재하는 파일: AWK_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: AWK_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: AWK_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: AWK_2025-02-20.png, 건너뜀.
# AXON 데이터 로드 중...
# 이미 존재하는 파일: AXON_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-03-20.png, 건너뜀.
# AXP 데이터 로드 중...
# 이미 존재하는 파일: AXP_2024-04-15.png, 건너뜀.
# 이미 존재하는 파일: AXP_2024-08-12.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-03-20.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-03-24.png, 건너뜀.
# AZO 데이터 로드 중...
# 이미 존재하는 파일: AZO_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: AZO_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: AZO_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: AZO_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: AZO_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AZO_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: AZO_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: AZO_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: AZO_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: AZO_2025-03-06.png, 건너뜀.
# 이미 존재하는 파일: AZO_2025-03-18.png, 건너뜀.
# BA 데이터 로드 중...
# 이미 존재하는 파일: BA_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-08-19.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-12-31.png, 건너뜀.
# 이미 존재하는 파일: BA_2025-03-19.png, 건너뜀.
# BAC 데이터 로드 중...
# 이미 존재하는 파일: BAC_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: BAC_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: BAC_2025-02-04.png, 건너뜀.
# BALL 데이터 로드 중...
# 이미 존재하는 파일: BALL_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-02-21.png, 건너뜀.
# BAX 데이터 로드 중...
# 이미 존재하는 파일: BAX_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-03-27.png, 건너뜀.
# BBY 데이터 로드 중...
# 이미 존재하는 파일: BBY_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-12-27.png, 건너뜀.
# 이미 존재하는 파일: BBY_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: BBY_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: BBY_2025-03-24.png, 건너뜀.
# 이미 존재하는 파일: BBY_2025-03-25.png, 건너뜀.
# BDX 데이터 로드 중...
# 이미 존재하는 파일: BDX_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: BDX_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: BDX_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: BDX_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: BDX_2025-03-10.png, 건너뜀.
# BEN 데이터 로드 중...
# 이미 존재하는 파일: BEN_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: BEN_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: BEN_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: BEN_2025-03-18.png, 건너뜀.
# BF-B 데이터 로드 중...
# 이미 존재하는 파일: BF-B_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-05-17.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-06-17.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-03-14.png, 건너뜀.
# BG 데이터 로드 중...
# 이미 존재하는 파일: BG_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-05-17.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: BG_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: BG_2025-03-10.png, 건너뜀.
# BIIB 데이터 로드 중...
# 이미 존재하는 파일: BIIB_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-01-02.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-03-18.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-03-27.png, 건너뜀.
# BK 데이터 로드 중...
# 이미 존재하는 파일: BK_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: BK_2025-03-03.png, 건너뜀.
# BKNG 데이터 로드 중...
# 이미 존재하는 파일: BKNG_2024-04-03.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-03-20.png, 건너뜀.
# BKR 데이터 로드 중...
# 이미 존재하는 파일: BKR_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-03-18.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-03-20.png, 건너뜀.
# BLDR 데이터 로드 중...
# 이미 존재하는 파일: BLDR_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-02-25.png, 건너뜀.
# BLK 데이터 로드 중...
# 이미 존재하는 파일: BLK_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: BLK_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: BLK_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: BLK_2025-03-18.png, 건너뜀.
# BMY 데이터 로드 중...
# 이미 존재하는 파일: BMY_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-12-18.png, 건너뜀.
# 이미 존재하는 파일: BMY_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: BMY_2025-02-28.png, 건너뜀.
# BR 데이터 로드 중...
# 이미 존재하는 파일: BR_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: BR_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: BR_2025-02-03.png, 건너뜀.
# BRK-B 데이터 로드 중...
# 이미 존재하는 파일: BRK-B_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-03-14.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-03-18.png, 건너뜀.
# BRO 데이터 로드 중...
# 이미 존재하는 파일: BRO_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: BRO_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: BRO_2025-03-18.png, 건너뜀.
# BSX 데이터 로드 중...
# 이미 존재하는 파일: BSX_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: BSX_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: BSX_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: BSX_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: BSX_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: BSX_2025-02-06.png, 건너뜀.
# BX 데이터 로드 중...
# 이미 존재하는 파일: BX_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-03-24.png, 건너뜀.
# BXP 데이터 로드 중...
# 이미 존재하는 파일: BXP_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: BXP_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: BXP_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: BXP_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: BXP_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: BXP_2025-03-18.png, 건너뜀.
# C 데이터 로드 중...
# 이미 존재하는 파일: C_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: C_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: C_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: C_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: C_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: C_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: C_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: C_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: C_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: C_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: C_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: C_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: C_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: C_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: C_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: C_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: C_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: C_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: C_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: C_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: C_2025-03-24.png, 건너뜀.
# CAG 데이터 로드 중...
# 이미 존재하는 파일: CAG_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-03-28.png, 건너뜀.
# CAH 데이터 로드 중...
# 이미 존재하는 파일: CAH_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: CAH_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: CAH_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: CAH_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: CAH_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: CAH_2025-03-13.png, 건너뜀.
# CARR 데이터 로드 중...
# 이미 존재하는 파일: CARR_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-04-15.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: CARR_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: CARR_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: CARR_2025-03-24.png, 건너뜀.
# CAT 데이터 로드 중...
# 이미 존재하는 파일: CAT_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: CAT_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: CAT_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: CAT_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: CAT_2025-03-24.png, 건너뜀.
# CB 데이터 로드 중...
# 이미 존재하는 파일: CB_2024-05-20.png, 건너뜀.
# 이미 존재하는 파일: CB_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: CB_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: CB_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: CB_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: CB_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: CB_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: CB_2025-02-25.png, 건너뜀.
# CBOE 데이터 로드 중...
# 이미 존재하는 파일: CBOE_2024-05-17.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2025-03-14.png, 건너뜀.
# CBRE 데이터 로드 중...
# 이미 존재하는 파일: CBRE_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-12-24.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2025-03-24.png, 건너뜀.
# CCI 데이터 로드 중...
# 이미 존재하는 파일: CCI_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: CCI_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: CCI_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: CCI_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: CCI_2025-03-04.png, 건너뜀.
# CCL 데이터 로드 중...
# 이미 존재하는 파일: CCL_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-05-20.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-08-12.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-03-20.png, 건너뜀.
# CDNS 데이터 로드 중...
# 이미 존재하는 파일: CDNS_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-08-22.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-03-18.png, 건너뜀.
# CDW 데이터 로드 중...
# 이미 존재하는 파일: CDW_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-03-18.png, 건너뜀.
# CEG 데이터 로드 중...
# 이미 존재하는 파일: CEG_2024-04-03.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-07-05.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-08-22.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-09-11.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-03-20.png, 건너뜀.
# CF 데이터 로드 중...
# 이미 존재하는 파일: CF_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-01-02.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-03-03.png, 건너뜀.
# CFG 데이터 로드 중...
# 이미 존재하는 파일: CFG_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: CFG_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: CFG_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: CFG_2025-03-12.png, 건너뜀.
# CHD 데이터 로드 중...
# 이미 존재하는 파일: CHD_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: CHD_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CHD_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CHD_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: CHD_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: CHD_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: CHD_2025-03-27.png, 건너뜀.
# CHRW 데이터 로드 중...
# 이미 존재하는 파일: CHRW_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2025-03-18.png, 건너뜀.
# CHTR 데이터 로드 중...
# 이미 존재하는 파일: CHTR_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-03-06.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-03-21.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-03-26.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-03-27.png, 건너뜀.
# CI 데이터 로드 중...
# 이미 존재하는 파일: CI_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: CI_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: CI_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: CI_2025-03-10.png, 건너뜀.
# CINF 데이터 로드 중...
# 이미 존재하는 파일: CINF_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-07-11.png, 건너뜀.
# ...
# 이미 존재하는 파일: STT_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: STT_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: STT_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: STT_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: STT_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: STT_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: STT_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: STT_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: STT_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: STT_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: STT_2025-03-24.png, 건너뜀.
# STX 데이터 로드 중...
# 이미 존재하는 파일: STX_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: STX_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: STX_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: STX_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: STX_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: STX_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: STX_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: STX_2025-03-03.png, 건너뜀.
# STZ 데이터 로드 중...
# 이미 존재하는 파일: STZ_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: STZ_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: STZ_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: STZ_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: STZ_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: STZ_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: STZ_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: STZ_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: STZ_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: STZ_2025-03-27.png, 건너뜀.
# SW 데이터 로드 중...
# 이미 존재하는 파일: SW_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: SW_2024-08-22.png, 건너뜀.
# 이미 존재하는 파일: SW_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: SW_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: SW_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: SW_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: SW_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: SW_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: SW_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: SW_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: SW_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: SW_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: SW_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: SW_2025-03-20.png, 건너뜀.
# SWK 데이터 로드 중...
# 이미 존재하는 파일: SWK_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: SWK_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: SWK_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: SWK_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: SWK_2025-02-21.png, 건너뜀.
# SWKS 데이터 로드 중...
# 이미 존재하는 파일: SWKS_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-03-24.png, 건너뜀.
# SYF 데이터 로드 중...
# 이미 존재하는 파일: SYF_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: SYF_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: SYF_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: SYF_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: SYF_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: SYF_2025-03-12.png, 건너뜀.
# SYK 데이터 로드 중...
# 이미 존재하는 파일: SYK_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: SYK_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: SYK_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: SYK_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: SYK_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: SYK_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: SYK_2025-01-16.png, 건너뜀.
# SYY 데이터 로드 중...
# 이미 존재하는 파일: SYY_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: SYY_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: SYY_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: SYY_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: SYY_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: SYY_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: SYY_2025-03-27.png, 건너뜀.
# T 데이터 로드 중...
# 이미 존재하는 파일: T_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: T_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: T_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: T_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: T_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: T_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: T_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: T_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: T_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: T_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: T_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: T_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: T_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: T_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: T_2025-03-28.png, 건너뜀.
# TAP 데이터 로드 중...
# 이미 존재하는 파일: TAP_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: TAP_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: TAP_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: TAP_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: TAP_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: TAP_2025-03-27.png, 건너뜀.
# TDG 데이터 로드 중...
# 이미 존재하는 파일: TDG_2024-04-08.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-10-01.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: TDG_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: TDG_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: TDG_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: TDG_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: TDG_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: TDG_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: TDG_2025-03-25.png, 건너뜀.
# TDY 데이터 로드 중...
# 이미 존재하는 파일: TDY_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: TDY_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: TDY_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: TDY_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: TDY_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: TDY_2025-03-12.png, 건너뜀.
# TECH 데이터 로드 중...
# 이미 존재하는 파일: TECH_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: TECH_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: TECH_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: TECH_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: TECH_2025-03-13.png, 건너뜀.
# 이미 존재하는 파일: TECH_2025-03-17.png, 건너뜀.
# TEL 데이터 로드 중...
# 이미 존재하는 파일: TEL_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: TEL_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: TEL_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: TEL_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: TEL_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: TEL_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: TEL_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: TEL_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: TEL_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: TEL_2025-03-24.png, 건너뜀.
# TER 데이터 로드 중...
# 이미 존재하는 파일: TER_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-12-24.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-02-27.png, 건너뜀.
# TFC 데이터 로드 중...
# 이미 존재하는 파일: TFC_2024-04-08.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: TFC_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: TFC_2025-01-21.png, 건너뜀.
# TGT 데이터 로드 중...
# 이미 존재하는 파일: TGT_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-08-19.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-12-27.png, 건너뜀.
# 이미 존재하는 파일: TGT_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: TGT_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: TGT_2025-03-03.png, 건너뜀.
# TJX 데이터 로드 중...
# 이미 존재하는 파일: TJX_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: TJX_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: TJX_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: TJX_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: TJX_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: TJX_2025-03-25.png, 건너뜀.
# TKO 데이터 로드 중...
# 이미 존재하는 파일: TKO_2024-04-09.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: TKO_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: TKO_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: TKO_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: TKO_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: TKO_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: TKO_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: TKO_2025-03-06.png, 건너뜀.
# TMO 데이터 로드 중...
# 이미 존재하는 파일: TMO_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: TMO_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: TMO_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: TMO_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: TMO_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: TMO_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: TMO_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: TMO_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: TMO_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: TMO_2025-03-06.png, 건너뜀.
# 이미 존재하는 파일: TMO_2025-03-17.png, 건너뜀.
# TMUS 데이터 로드 중...
# 이미 존재하는 파일: TMUS_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: TMUS_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: TMUS_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: TMUS_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: TMUS_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: TMUS_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: TMUS_2025-03-18.png, 건너뜀.
# 이미 존재하는 파일: TMUS_2025-03-28.png, 건너뜀.
# TPL 데이터 로드 중...
# 이미 존재하는 파일: TPL_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-03-18.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-03-26.png, 건너뜀.
# TPR 데이터 로드 중...
# 이미 존재하는 파일: TPR_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-12-02.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: TPR_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: TPR_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: TPR_2025-01-29.png, 건너뜀.
# TRGP 데이터 로드 중...
# 이미 존재하는 파일: TRGP_2024-04-04.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2025-03-25.png, 건너뜀.
# TRMB 데이터 로드 중...
# 이미 존재하는 파일: TRMB_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2025-03-17.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2025-03-24.png, 건너뜀.
# TROW 데이터 로드 중...
# 이미 존재하는 파일: TROW_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: TROW_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: TROW_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: TROW_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: TROW_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: TROW_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: TROW_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: TROW_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: TROW_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: TROW_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: TROW_2025-03-25.png, 건너뜀.
# TRV 데이터 로드 중...
# 이미 존재하는 파일: TRV_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: TRV_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: TRV_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: TRV_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: TRV_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: TRV_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: TRV_2025-02-28.png, 건너뜀.
# TSCO 데이터 로드 중...
# 이미 존재하는 파일: TSCO_2024-04-11.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-08-22.png, 건너뜀.
# 이미 존재하는 파일: TSCO_2024-09-12.png, 건너뜀.
# TSLA 데이터 로드 중...
# TSN 데이터 로드 중...
# TT 데이터 로드 중...
# TTWO 데이터 로드 중...
# TXN 데이터 로드 중...
# TXT 데이터 로드 중...
# TYL 데이터 로드 중...
# UAL 데이터 로드 중...
# UBER 데이터 로드 중...
# UDR 데이터 로드 중...
# UHS 데이터 로드 중...
# ULTA 데이터 로드 중...
# UNH 데이터 로드 중...
# UNP 데이터 로드 중...
# UPS 데이터 로드 중...
# URI 데이터 로드 중...
# USB 데이터 로드 중...
# V 데이터 로드 중...
# VICI 데이터 로드 중...
# VLO 데이터 로드 중...
# VLTO 데이터 로드 중...
# VMC 데이터 로드 중...
# VRSK 데이터 로드 중...
# VRSN 데이터 로드 중...
# VRTX 데이터 로드 중...
# VST 데이터 로드 중...
# VTR 데이터 로드 중...
# VTRS 데이터 로드 중...
# VZ 데이터 로드 중...
# WAB 데이터 로드 중...
# WAT 데이터 로드 중...
# WBA 데이터 로드 중...
# WBD 데이터 로드 중...
# WDAY 데이터 로드 중...
# WDC 데이터 로드 중...
# WEC 데이터 로드 중...
# WELL 데이터 로드 중...
# WFC 데이터 로드 중...
# WM 데이터 로드 중...
# WMB 데이터 로드 중...
# WMT 데이터 로드 중...
# WRB 데이터 로드 중...
# WSM 데이터 로드 중...
# WST 데이터 로드 중...
# WTW 데이터 로드 중...
# WY 데이터 로드 중...
# WYNN 데이터 로드 중...
# XEL 데이터 로드 중...
# XOM 데이터 로드 중...
# XYL 데이터 로드 중...
# YUM 데이터 로드 중...
# ZBH 데이터 로드 중...
# ZBRA 데이터 로드 중...
# ZTS 데이터 로드 중...
# 총 732장의 상승 패턴 이미지 저장 완료!

# %%
# 테스트용 하락패턴 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 저장할 디렉토리 설정 (하락 패턴 이미지 저장)
output_dir = "./data/price_2to3percent_drop_patterns_test"
os.makedirs(output_dir, exist_ok=True)

# 저장된 CSV 파일 경로 (S&P 500 주식 데이터 폴더)
data_dir = "./data/sp500_stocks_test/"

# 저장된 이미지 개수 제한
MAX_IMAGES = 100000000
saved_image_count = 0

# 봉 개수 설정 (전날 대비 -2~-3% 이상 하락한 날 기준으로 과거 20일)
N_CANDLES = 20

# 기존 저장된 이미지 확인 (중복 방지)
existing_images = set(os.listdir(output_dir))

# 모든 CSV 파일 가져오기 (S&P 500 종목 전체 대상)
csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# 모든 CSV 파일에 대해 데이터 분석
for csv_file in csv_files:
    if saved_image_count >= MAX_IMAGES:
        print("최대 저장 개수(100000000장) 도달, 저장 중단")
        break

    ticker = csv_file.replace(".csv", "")  # 종목명 추출
    file_path = os.path.join(data_dir, csv_file)

    print(f"{ticker} 데이터 로드 중...")
    df = pd.read_csv(file_path)

    # 날짜 변환 및 인덱스 설정
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

    # 전날 대비 하락한 날 찾기
    df['pct_change'] = df['Open'].pct_change() * 100  # 퍼센트 변환
    drop_days = df[(df['pct_change'] >= -3)&(df['pct_change'] < -2)].index  # -2~-3% 이상 하락한 날짜 리스트

    # 하락한 날 기준으로 과거 20일의 봉차트 저장
    for drop_date in drop_days:
        if saved_image_count >= MAX_IMAGES:
            print("최대 저장 개수(100000000장) 도달, 저장 중단")
            break

        # 파일명 설정
        file_name = f"{ticker}_{drop_date.strftime('%Y-%m-%d')}.png"
        image_path = os.path.join(output_dir, file_name)  # 이미지 저장 경로

        # 중복 확인: 파일이 이미 존재하면 건너뛰기
        if file_name in existing_images:
            print(f"이미 존재하는 파일: {file_name}, 건너뜀.")
            continue

        # 해당 날짜 기준으로 과거 20일 데이터 가져오기
        end_idx = df.index.get_loc(drop_date)
        start_idx = max(end_idx - N_CANDLES, 0)  # 최소 20개 봉이 있어야 함

        if start_idx == 0:
            continue  # 데이터가 부족하면 스킵

        df_fixed = df.iloc[start_idx:end_idx]

        # 캔들스틱 차트 스타일 지정 (하락 패턴 강조)
        mc = mpf.make_marketcolors(up='g', down='r', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # 캔들스틱 차트 저장
        mpf.plot(
            df_fixed,
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=image_path  # 수정된 이미지 저장 경로
        )

        # 이미지 크기 조정 (CNN 학습용 224x224 픽셀)
        img = Image.open(image_path)
        img = img.resize((224, 224))
        img.save(image_path)

        saved_image_count += 1
        existing_images.add(file_name)  # 새로 생성된 파일 추가

print(f"총 {saved_image_count}장의 하락 패턴 이미지 저장 완료!")
# Out:
# A 데이터 로드 중...
# 이미 존재하는 파일: A_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: A_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: A_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: A_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: A_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: A_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: A_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: A_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: A_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: A_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: A_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: A_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: A_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: A_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: A_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: A_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: A_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: A_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: A_2025-03-13.png, 건너뜀.
# 이미 존재하는 파일: A_2025-03-31.png, 건너뜀.
# AAPL 데이터 로드 중...
# 이미 존재하는 파일: AAPL_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-03-14.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-03-31.png, 건너뜀.
# ABBV 데이터 로드 중...
# 이미 존재하는 파일: ABBV_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-03-26.png, 건너뜀.
# ABNB 데이터 로드 중...
# 이미 존재하는 파일: ABNB_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2025-03-14.png, 건너뜀.
# ABT 데이터 로드 중...
# 이미 존재하는 파일: ABT_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: ABT_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: ABT_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: ABT_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: ABT_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: ABT_2025-03-05.png, 건너뜀.
# ACGL 데이터 로드 중...
# 이미 존재하는 파일: ACGL_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-07-05.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2025-03-19.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2025-03-31.png, 건너뜀.
# ACN 데이터 로드 중...
# 이미 존재하는 파일: ACN_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-05-20.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: ACN_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: ACN_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: ACN_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: ACN_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: ACN_2025-03-14.png, 건너뜀.
# ADBE 데이터 로드 중...
# 이미 존재하는 파일: ADBE_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2025-03-11.png, 건너뜀.
# ADI 데이터 로드 중...
# 이미 존재하는 파일: ADI_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-03-21.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-03-27.png, 건너뜀.
# ADM 데이터 로드 중...
# 이미 존재하는 파일: ADM_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-06-17.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ADM_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-03-13.png, 건너뜀.
# ADP 데이터 로드 중...
# 이미 존재하는 파일: ADP_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: ADP_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: ADP_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: ADP_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: ADP_2024-12-19.png, 건너뜀.
# ADSK 데이터 로드 중...
# 이미 존재하는 파일: ADSK_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2025-03-21.png, 건너뜀.
# AEE 데이터 로드 중...
# 이미 존재하는 파일: AEE_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AEE_2025-01-23.png, 건너뜀.
# AEP 데이터 로드 중...
# 이미 존재하는 파일: AEP_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: AEP_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: AEP_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: AEP_2025-03-25.png, 건너뜀.
# AES 데이터 로드 중...
# 이미 존재하는 파일: AES_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-03-31.png, 건너뜀.
# AFL 데이터 로드 중...
# 이미 존재하는 파일: AFL_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AFL_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: AFL_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: AFL_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: AFL_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: AFL_2025-03-05.png, 건너뜀.
# AIG 데이터 로드 중...
# 이미 존재하는 파일: AIG_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: AIG_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: AIG_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: AIG_2025-02-18.png, 건너뜀.
# AIZ 데이터 로드 중...
# 이미 존재하는 파일: AIZ_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2025-03-31.png, 건너뜀.
# AJG 데이터 로드 중...
# 이미 존재하는 파일: AJG_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: AJG_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AJG_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: AJG_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: AJG_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: AJG_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AJG_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: AJG_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: AJG_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: AJG_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: AJG_2025-03-05.png, 건너뜀.
# AKAM 데이터 로드 중...
# 이미 존재하는 파일: AKAM_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2025-03-13.png, 건너뜀.
# ALB 데이터 로드 중...
# 이미 존재하는 파일: ALB_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-06-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-10-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-03-21.png, 건너뜀.
# ALGN 데이터 로드 중...
# 이미 존재하는 파일: ALGN_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-05-17.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-03-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-03-28.png, 건너뜀.
# ALL 데이터 로드 중...
# 이미 존재하는 파일: ALL_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: ALL_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: ALL_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: ALL_2025-03-19.png, 건너뜀.
# ALLE 데이터 로드 중...
# 이미 존재하는 파일: ALLE_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-03-31.png, 건너뜀.
# AMAT 데이터 로드 중...
# 이미 존재하는 파일: AMAT_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-06-10.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-03-27.png, 건너뜀.
# AMCR 데이터 로드 중...
# 이미 존재하는 파일: AMCR_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2025-03-12.png, 건너뜀.
# AMD 데이터 로드 중...
# 이미 존재하는 파일: AMD_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-06-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-02-26.png, 건너뜀.
# AME 데이터 로드 중...
# 이미 존재하는 파일: AME_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: AME_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: AME_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: AME_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: AME_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: AME_2025-03-13.png, 건너뜀.
# AMGN 데이터 로드 중...
# 이미 존재하는 파일: AMGN_2024-04-03.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-03-26.png, 건너뜀.
# AMP 데이터 로드 중...
# 이미 존재하는 파일: AMP_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: AMP_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-03-27.png, 건너뜀.
# AMT 데이터 로드 중...
# 이미 존재하는 파일: AMT_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: AMT_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: AMT_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: AMT_2025-03-12.png, 건너뜀.
# AMZN 데이터 로드 중...
# 이미 존재하는 파일: AMZN_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-03-27.png, 건너뜀.
# ANET 데이터 로드 중...
# 이미 존재하는 파일: ANET_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-26.png, 건너뜀.
# ANSS 데이터 로드 중...
# 이미 존재하는 파일: ANSS_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2025-03-04.png, 건너뜀.
# AON 데이터 로드 중...
# 이미 존재하는 파일: AON_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-12-10.png, 건너뜀.
# AOS 데이터 로드 중...
# 이미 존재하는 파일: AOS_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: AOS_2025-03-31.png, 건너뜀.
# APA 데이터 로드 중...
# 이미 존재하는 파일: APA_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-03-31.png, 건너뜀.
# APD 데이터 로드 중...
# 이미 존재하는 파일: APD_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: APD_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: APD_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: APD_2025-03-11.png, 건너뜀.
# APH 데이터 로드 중...
# 이미 존재하는 파일: APH_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-03-27.png, 건너뜀.
# APO 데이터 로드 중...
# 이미 존재하는 파일: APO_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-03-06.png, 건너뜀.
# APTV 데이터 로드 중...
# 이미 존재하는 파일: APTV_2024-04-11.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-09-11.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-03-28.png, 건너뜀.
# ARE 데이터 로드 중...
# 이미 존재하는 파일: ARE_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: ARE_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ARE_2025-01-31.png, 건너뜀.
# ATO 데이터 로드 중...
# 이미 존재하는 파일: ATO_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: ATO_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: ATO_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: ATO_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: ATO_2025-01-24.png, 건너뜀.
# AVB 데이터 로드 중...
# 이미 존재하는 파일: AVB_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: AVB_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: AVB_2025-01-16.png, 건너뜀.
# AVGO 데이터 로드 중...
# 이미 존재하는 파일: AVGO_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-11-29.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-03-26.png, 건너뜀.
# AVY 데이터 로드 중...
# 이미 존재하는 파일: AVY_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: AVY_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: AVY_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: AVY_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: AVY_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: AVY_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: AVY_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: AVY_2025-03-04.png, 건너뜀.
# AWK 데이터 로드 중...
# 이미 존재하는 파일: AWK_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: AWK_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: AWK_2025-02-27.png, 건너뜀.
# AXON 데이터 로드 중...
# 이미 존재하는 파일: AXON_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-12-24.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-03-14.png, 건너뜀.
# AXP 데이터 로드 중...
# 이미 존재하는 파일: AXP_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: AXP_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: AXP_2024-09-11.png, 건너뜀.
# 이미 존재하는 파일: AXP_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: AXP_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: AXP_2025-03-10.png, 건너뜀.
# AZO 데이터 로드 중...
# 이미 존재하는 파일: AZO_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: AZO_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: AZO_2025-03-04.png, 건너뜀.
# BA 데이터 로드 중...
# 이미 존재하는 파일: BA_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-10-01.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: BA_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: BA_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: BA_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: BA_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: BA_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: BA_2025-03-27.png, 건너뜀.
# BAC 데이터 로드 중...
# 이미 존재하는 파일: BAC_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-09-11.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: BAC_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: BAC_2025-03-06.png, 건너뜀.
# 이미 존재하는 파일: BAC_2025-03-10.png, 건너뜀.
# BALL 데이터 로드 중...
# 이미 존재하는 파일: BALL_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: BALL_2025-02-07.png, 건너뜀.
# BAX 데이터 로드 중...
# 이미 존재하는 파일: BAX_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-04-15.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: BAX_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-03-21.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-03-26.png, 건너뜀.
# BBY 데이터 로드 중...
# 이미 존재하는 파일: BBY_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-07-30.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: BBY_2025-01-06.png, 건너뜀.
# BDX 데이터 로드 중...
# 이미 존재하는 파일: BDX_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: BDX_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: BDX_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: BDX_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: BDX_2025-03-05.png, 건너뜀.
# BEN 데이터 로드 중...
# 이미 존재하는 파일: BEN_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: BEN_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: BEN_2025-03-04.png, 건너뜀.
# BF-B 데이터 로드 중...
# 이미 존재하는 파일: BF-B_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2024-12-24.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-03-13.png, 건너뜀.
# BG 데이터 로드 중...
# 이미 존재하는 파일: BG_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-09-11.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: BG_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: BG_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: BG_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: BG_2025-02-03.png, 건너뜀.
# BIIB 데이터 로드 중...
# 이미 존재하는 파일: BIIB_2024-04-03.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-04-15.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-06-10.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-03-26.png, 건너뜀.
# BK 데이터 로드 중...
# 이미 존재하는 파일: BK_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: BK_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: BK_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: BK_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: BK_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: BK_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: BK_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: BK_2025-03-31.png, 건너뜀.
# BKNG 데이터 로드 중...
# 이미 존재하는 파일: BKNG_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2025-03-19.png, 건너뜀.
# BKR 데이터 로드 중...
# 이미 존재하는 파일: BKR_2024-04-15.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: BKR_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-03-27.png, 건너뜀.
# BLDR 데이터 로드 중...
# 이미 존재하는 파일: BLDR_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-05-17.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-03-14.png, 건너뜀.
# BLK 데이터 로드 중...
# 이미 존재하는 파일: BLK_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BLK_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: BLK_2025-03-04.png, 건너뜀.
# BMY 데이터 로드 중...
# 이미 존재하는 파일: BMY_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-12-31.png, 건너뜀.
# 이미 존재하는 파일: BMY_2025-02-11.png, 건너뜀.
# BR 데이터 로드 중...
# 이미 존재하는 파일: BR_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: BR_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: BR_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BR_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: BR_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: BR_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: BR_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: BR_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: BR_2025-03-12.png, 건너뜀.
# BRK-B 데이터 로드 중...
# 이미 존재하는 파일: BRK-B_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: BRK-B_2025-03-31.png, 건너뜀.
# BRO 데이터 로드 중...
# 이미 존재하는 파일: BRO_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: BRO_2024-11-15.png, 건너뜀.
# BSX 데이터 로드 중...
# 이미 존재하는 파일: BSX_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: BSX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: BSX_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: BSX_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: BSX_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: BSX_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: BSX_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: BSX_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: BSX_2025-03-28.png, 건너뜀.
# BX 데이터 로드 중...
# 이미 존재하는 파일: BX_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-05-20.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-12-18.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-03-06.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-03-27.png, 건너뜀.
# BXP 데이터 로드 중...
# 이미 존재하는 파일: BXP_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: BXP_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: BXP_2025-01-10.png, 건너뜀.
# C 데이터 로드 중...
# 이미 존재하는 파일: C_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: C_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: C_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: C_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: C_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: C_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: C_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: C_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: C_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: C_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: C_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: C_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: C_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: C_2025-03-27.png, 건너뜀.
# 이미 존재하는 파일: C_2025-03-31.png, 건너뜀.
# CAG 데이터 로드 중...
# 이미 존재하는 파일: CAG_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: CAG_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-03-05.png, 건너뜀.
# CAH 데이터 로드 중...
# 이미 존재하는 파일: CAH_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: CAH_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: CAH_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: CAH_2025-03-05.png, 건너뜀.
# CARR 데이터 로드 중...
# 이미 존재하는 파일: CARR_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: CARR_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: CARR_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: CARR_2025-02-28.png, 건너뜀.
# CAT 데이터 로드 중...
# 이미 존재하는 파일: CAT_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: CAT_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: CAT_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: CAT_2025-03-13.png, 건너뜀.
# CB 데이터 로드 중...
# 이미 존재하는 파일: CB_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CB_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: CB_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CB_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: CB_2024-12-10.png, 건너뜀.
# CBOE 데이터 로드 중...
# 이미 존재하는 파일: CBOE_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: CBOE_2025-03-24.png, 건너뜀.
# CBRE 데이터 로드 중...
# 이미 존재하는 파일: CBRE_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-04-11.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2025-03-14.png, 건너뜀.
# CCI 데이터 로드 중...
# 이미 존재하는 파일: CCI_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-05-20.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: CCI_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: CCI_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: CCI_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: CCI_2025-01-29.png, 건너뜀.
# CCL 데이터 로드 중...
# 이미 존재하는 파일: CCL_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-12-26.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-03-06.png, 건너뜀.
# CDNS 데이터 로드 중...
# 이미 존재하는 파일: CDNS_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-03-27.png, 건너뜀.
# CDW 데이터 로드 중...
# 이미 존재하는 파일: CDW_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-03-21.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-03-27.png, 건너뜀.
# CEG 데이터 로드 중...
# 이미 존재하는 파일: CEG_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-06-17.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-11-29.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-03-10.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-03-26.png, 건너뜀.
# CF 데이터 로드 중...
# 이미 존재하는 파일: CF_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: CF_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-03-26.png, 건너뜀.
# CFG 데이터 로드 중...
# 이미 존재하는 파일: CFG_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-04-12.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: CFG_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: CFG_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: CFG_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: CFG_2025-03-28.png, 건너뜀.
# CHD 데이터 로드 중...
# 이미 존재하는 파일: CHD_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: CHD_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: CHD_2024-07-30.png, 건너뜀.
# 이미 존재하는 파일: CHD_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: CHD_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CHD_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: CHD_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: CHD_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: CHD_2025-03-12.png, 건너뜀.
# CHRW 데이터 로드 중...
# 이미 존재하는 파일: CHRW_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2025-03-05.png, 건너뜀.
# CHTR 데이터 로드 중...
# 이미 존재하는 파일: CHTR_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-03-05.png, 건너뜀.
# CI 데이터 로드 중...
# 이미 존재하는 파일: CI_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: CI_2025-02-18.png, 건너뜀.
# CINF 데이터 로드 중...
# 이미 존재하는 파일: CINF_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-12-18.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: CINF_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: CINF_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: CINF_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: CINF_2025-02-13.png, 건너뜀.
# CL 데이터 로드 중...
# 이미 존재하는 파일: CL_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: CL_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CL_2024-10-25.png, 건너뜀.
# CLX 데이터 로드 중...
# 이미 존재하는 파일: CLX_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CLX_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: CLX_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: CLX_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CLX_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: CLX_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: CLX_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: CLX_2025-03-19.png, 건너뜀.
# CMCSA 데이터 로드 중...
# 이미 존재하는 파일: CMCSA_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2025-03-05.png, 건너뜀.
# CME 데이터 로드 중...
# 이미 존재하는 파일: CME_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: CME_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CME_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: CME_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: CME_2025-03-05.png, 건너뜀.
# CMG 데이터 로드 중...
# 이미 존재하는 파일: CMG_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: CMG_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: CMG_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: CMG_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: CMG_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: CMG_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: CMG_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: CMG_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: CMG_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: CMG_2025-03-07.png, 건너뜀.
# CMI 데이터 로드 중...
# 이미 존재하는 파일: CMI_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CMI_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: CMI_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: CMI_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: CMI_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: CMI_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: CMI_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: CMI_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: CMI_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: CMI_2025-01-27.png, 건너뜀.
# CMS 데이터 로드 중...
# 이미 존재하는 파일: CMS_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CMS_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CMS_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: CMS_2025-03-05.png, 건너뜀.
# CNC 데이터 로드 중...
# 이미 존재하는 파일: CNC_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: CNC_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: CNC_2025-03-12.png, 건너뜀.
# CNP 데이터 로드 중...
# 이미 존재하는 파일: CNP_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: CNP_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: CNP_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: CNP_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CNP_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: CNP_2024-12-04.png, 건너뜀.
# COF 데이터 로드 중...
# ...
# 이미 존재하는 파일: NSC_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: NSC_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: NSC_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: NSC_2025-02-03.png, 건너뜀.
# NTAP 데이터 로드 중...
# 이미 존재하는 파일: NTAP_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2025-03-27.png, 건너뜀.
# NTRS 데이터 로드 중...
# 이미 존재하는 파일: NTRS_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2025-02-26.png, 건너뜀.
# NUE 데이터 로드 중...
# 이미 존재하는 파일: NUE_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: NUE_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: NUE_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: NUE_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: NUE_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: NUE_2025-03-11.png, 건너뜀.
# NVDA 데이터 로드 중...
# 이미 존재하는 파일: NVDA_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-03-11.png, 건너뜀.
# NVR 데이터 로드 중...
# 이미 존재하는 파일: NVR_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: NVR_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: NVR_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: NVR_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: NVR_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: NVR_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: NVR_2025-03-31.png, 건너뜀.
# NWS 데이터 로드 중...
# 이미 존재하는 파일: NWS_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: NWS_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: NWS_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: NWS_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: NWS_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: NWS_2024-11-14.png, 건너뜀.
# NWSA 데이터 로드 중...
# 이미 존재하는 파일: NWSA_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: NWSA_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: NWSA_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: NWSA_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: NWSA_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: NWSA_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: NWSA_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: NWSA_2025-02-07.png, 건너뜀.
# NXPI 데이터 로드 중...
# 이미 존재하는 파일: NXPI_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2025-03-28.png, 건너뜀.
# O 데이터 로드 중...
# 이미 존재하는 파일: O_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: O_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: O_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: O_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: O_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: O_2025-01-16.png, 건너뜀.
# ODFL 데이터 로드 중...
# 이미 존재하는 파일: ODFL_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2025-02-25.png, 건너뜀.
# OKE 데이터 로드 중...
# 이미 존재하는 파일: OKE_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: OKE_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: OKE_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: OKE_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: OKE_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: OKE_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: OKE_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: OKE_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: OKE_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: OKE_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: OKE_2025-03-28.png, 건너뜀.
# OMC 데이터 로드 중...
# 이미 존재하는 파일: OMC_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: OMC_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: OMC_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: OMC_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: OMC_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: OMC_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: OMC_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: OMC_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: OMC_2025-02-11.png, 건너뜀.
# ON 데이터 로드 중...
# 이미 존재하는 파일: ON_2024-04-02.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-04-03.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-10-07.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-12-31.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-03-06.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-03-12.png, 건너뜀.
# ORCL 데이터 로드 중...
# 이미 존재하는 파일: ORCL_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-11-29.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2025-02-25.png, 건너뜀.
# ORLY 데이터 로드 중...
# 이미 존재하는 파일: ORLY_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: ORLY_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: ORLY_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: ORLY_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: ORLY_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: ORLY_2024-12-18.png, 건너뜀.
# 이미 존재하는 파일: ORLY_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: ORLY_2025-03-05.png, 건너뜀.
# OTIS 데이터 로드 중...
# 이미 존재하는 파일: OTIS_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: OTIS_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: OTIS_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: OTIS_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: OTIS_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: OTIS_2025-03-12.png, 건너뜀.
# OXY 데이터 로드 중...
# 이미 존재하는 파일: OXY_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: OXY_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: OXY_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: OXY_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: OXY_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: OXY_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: OXY_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: OXY_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: OXY_2025-03-31.png, 건너뜀.
# PANW 데이터 로드 중...
# 이미 존재하는 파일: PANW_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: PANW_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: PANW_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: PANW_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: PANW_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: PANW_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-03-11.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-03-13.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-03-21.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-03-31.png, 건너뜀.
# PARA 데이터 로드 중...
# 이미 존재하는 파일: PARA_2024-04-10.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-05-20.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-09-11.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-12-24.png, 건너뜀.
# 이미 존재하는 파일: PARA_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: PARA_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: PARA_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: PARA_2025-03-25.png, 건너뜀.
# 이미 존재하는 파일: PARA_2025-03-28.png, 건너뜀.
# PAYC 데이터 로드 중...
# 이미 존재하는 파일: PAYC_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-04-15.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2025-02-10.png, 건너뜀.
# PAYX 데이터 로드 중...
# 이미 존재하는 파일: PAYX_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: PAYX_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: PAYX_2025-03-05.png, 건너뜀.
# PCAR 데이터 로드 중...
# 이미 존재하는 파일: PCAR_2024-04-03.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2025-03-04.png, 건너뜀.
# PCG 데이터 로드 중...
# 이미 존재하는 파일: PCG_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: PCG_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: PCG_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: PCG_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: PCG_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: PCG_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: PCG_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: PCG_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: PCG_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: PCG_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: PCG_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: PCG_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: PCG_2025-03-05.png, 건너뜀.
# PEG 데이터 로드 중...
# 이미 존재하는 파일: PEG_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: PEG_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: PEG_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: PEG_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: PEG_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: PEG_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: PEG_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: PEG_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: PEG_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: PEG_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: PEG_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: PEG_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: PEG_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: PEG_2025-03-26.png, 건너뜀.
# PEP 데이터 로드 중...
# 이미 존재하는 파일: PEP_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: PEP_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: PEP_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: PEP_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: PEP_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: PEP_2025-03-05.png, 건너뜀.
# PFE 데이터 로드 중...
# 이미 존재하는 파일: PFE_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: PFE_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: PFE_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: PFE_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: PFE_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: PFE_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: PFE_2025-03-26.png, 건너뜀.
# PFG 데이터 로드 중...
# 이미 존재하는 파일: PFG_2024-04-05.png, 건너뜀.
# 이미 존재하는 파일: PFG_2024-04-16.png, 건너뜀.
# 이미 존재하는 파일: PFG_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: PFG_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: PFG_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: PFG_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: PFG_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: PFG_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: PFG_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: PFG_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: PFG_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: PFG_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: PFG_2025-03-10.png, 건너뜀.
# PG 데이터 로드 중...
# PGR 데이터 로드 중...
# PH 데이터 로드 중...
# PHM 데이터 로드 중...
# PKG 데이터 로드 중...
# PLD 데이터 로드 중...
# PLTR 데이터 로드 중...
# PM 데이터 로드 중...
# PNC 데이터 로드 중...
# PNR 데이터 로드 중...
# PNW 데이터 로드 중...
# PODD 데이터 로드 중...
# POOL 데이터 로드 중...
# PPG 데이터 로드 중...
# PPL 데이터 로드 중...
# PRU 데이터 로드 중...
# PSA 데이터 로드 중...
# PSX 데이터 로드 중...
# PTC 데이터 로드 중...
# PWR 데이터 로드 중...
# PYPL 데이터 로드 중...
# QCOM 데이터 로드 중...
# RCL 데이터 로드 중...
# REG 데이터 로드 중...
# REGN 데이터 로드 중...
# RF 데이터 로드 중...
# RJF 데이터 로드 중...
# RL 데이터 로드 중...
# RMD 데이터 로드 중...
# ROK 데이터 로드 중...
# ROL 데이터 로드 중...
# ROP 데이터 로드 중...
# ROST 데이터 로드 중...
# RSG 데이터 로드 중...
# RTX 데이터 로드 중...
# RVTY 데이터 로드 중...
# SBAC 데이터 로드 중...
# SBUX 데이터 로드 중...
# SCHW 데이터 로드 중...
# SHW 데이터 로드 중...
# SJM 데이터 로드 중...
# SLB 데이터 로드 중...
# SMCI 데이터 로드 중...
# SNA 데이터 로드 중...
# SNPS 데이터 로드 중...
# SO 데이터 로드 중...
# SOLV 데이터 로드 중...
# SPG 데이터 로드 중...
# SPGI 데이터 로드 중...
# SRE 데이터 로드 중...
# STE 데이터 로드 중...
# STLD 데이터 로드 중...
# STT 데이터 로드 중...
# STX 데이터 로드 중...
# STZ 데이터 로드 중...
# SW 데이터 로드 중...
# SWK 데이터 로드 중...
# SWKS 데이터 로드 중...
# SYF 데이터 로드 중...
# SYK 데이터 로드 중...
# SYY 데이터 로드 중...
# T 데이터 로드 중...
# TAP 데이터 로드 중...
# TDG 데이터 로드 중...
# TDY 데이터 로드 중...
# TECH 데이터 로드 중...
# TEL 데이터 로드 중...
# TER 데이터 로드 중...
# TFC 데이터 로드 중...
# TGT 데이터 로드 중...
# TJX 데이터 로드 중...
# TKO 데이터 로드 중...
# TMO 데이터 로드 중...
# TMUS 데이터 로드 중...
# TPL 데이터 로드 중...
# TPR 데이터 로드 중...
# TRGP 데이터 로드 중...
# TRMB 데이터 로드 중...
# TROW 데이터 로드 중...
# TRV 데이터 로드 중...
# TSCO 데이터 로드 중...
# TSLA 데이터 로드 중...
# TSN 데이터 로드 중...
# TT 데이터 로드 중...
# TTWO 데이터 로드 중...
# TXN 데이터 로드 중...
# TXT 데이터 로드 중...
# TYL 데이터 로드 중...
# UAL 데이터 로드 중...
# UBER 데이터 로드 중...
# UDR 데이터 로드 중...
# UHS 데이터 로드 중...
# ULTA 데이터 로드 중...
# UNH 데이터 로드 중...
# UNP 데이터 로드 중...
# UPS 데이터 로드 중...
# URI 데이터 로드 중...
# USB 데이터 로드 중...
# V 데이터 로드 중...
# VICI 데이터 로드 중...
# VLO 데이터 로드 중...
# VLTO 데이터 로드 중...
# VMC 데이터 로드 중...
# VRSK 데이터 로드 중...
# VRSN 데이터 로드 중...
# VRTX 데이터 로드 중...
# VST 데이터 로드 중...
# VTR 데이터 로드 중...
# VTRS 데이터 로드 중...
# VZ 데이터 로드 중...
# WAB 데이터 로드 중...
# WAT 데이터 로드 중...
# WBA 데이터 로드 중...
# WBD 데이터 로드 중...
# WDAY 데이터 로드 중...
# WDC 데이터 로드 중...
# WEC 데이터 로드 중...
# WELL 데이터 로드 중...
# WFC 데이터 로드 중...
# WM 데이터 로드 중...

# %%
import os
import time
import yfinance as yf
import pandas as pd
import mplfinance as mpf
from PIL import Image
from datetime import timedelta
from bs4 import BeautifulSoup
from curl_cffi.requests import Session

# 기준 날짜 설정
target_date = pd.to_datetime("2025-05-08")

# 저장 경로 설정
base_dir = "./data/recent"
for category in ["surge", "drop", "neutral"]:
    os.makedirs(os.path.join(base_dir, category), exist_ok=True)

N_CANDLES = 20
saved_count = 0

# S&P 500 종목 리스트 가져오기
def get_sp500_tickers():
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url)
    df = tables[0]
    tickers = df["Symbol"].tolist()
    return [t.replace(".", "-") for t in tickers]

sp500_tickers = get_sp500_tickers()
print("S&P 500 종목 개수:", len(sp500_tickers))
print("샘플 종목:", sp500_tickers[:5])

session = Session()
for ticker in sp500_tickers:
    try:
        print(f"\n{ticker} 데이터 다운로드 중...")
        time.sleep(1)

        df = yf.download(
            ticker,
            start=target_date - timedelta(days=40),
            end=target_date + timedelta(days=2),
            group_by='column'
        )

        # MultiIndex 컬럼 평탄화
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = [col[0] for col in df.columns]

        if df.empty:
            print(f"{ticker}: 데이터 없음")
            continue

        required_cols = ["Open", "High", "Low", "Close"]
        if not all(col in df.columns for col in required_cols):
            print(f"{ticker}: OHLC 컬럼 누락 - 현재 컬럼: {df.columns.tolist()}")
            continue

        available_dates = df.index[df.index <= target_date] # ~ <= 2025-05-08
        if len(available_dates) == 0:
            print(f"{ticker}: {target_date.date()} 이전 거래일 없음")
            continue

        actual_date = available_dates[-1] # 2025-05-08
        end_idx = df.index.get_loc(actual_date) # 2025-05-08

        if end_idx < N_CANDLES:
            print(f"{ticker}: 20봉 이상 데이터 부족")
            continue

        df_slice = df.iloc[end_idx - N_CANDLES:end_idx].copy() # ~ < 2025-05-08

        # 강제 정제: 인덱스 타입, 컬럼 선택, float64 변환, NaN 제거
        df_slice.index = pd.to_datetime(df_slice.index)
        df_slice = df_slice[required_cols].copy()
        df_slice = df_slice.astype("float64")
        df_slice.dropna(inplace=True)

        if len(df_slice) < N_CANDLES:
            print(f"{ticker}: 정제 후 유효한 캔들 수 부족")
            continue

        close_today = df.at[df.index[end_idx], "Close"] # 2025-05-08
        close_yesterday = df.at[df.index[end_idx - 1], "Close"] # 2025-05-07
        pct_change = ((close_today - close_yesterday) / close_yesterday) * 100

        if pct_change > 2:
            label = "surge"
        elif pct_change < -2:
            label = "drop"
        else:
            label = "neutral"

        filename = f"{ticker}_{actual_date.date()}.png"
        out_path = os.path.join(base_dir, label, filename)

        mc = mpf.make_marketcolors(up='g', down='r', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        mpf.plot(
            df_slice, # ~ < 2025-05-08
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=out_path
        )

        img = Image.open(out_path)
        img = img.resize((224, 224))
        img.save(out_path)

        print(f"저장 완료: {label}/{filename}")
        saved_count += 1

    except Exception as e:
        print(f"⚠️ {ticker} 처리 중 오류: {e}")

print(f"\n📦 총 {saved_count}개 이미지 저장 완료")


'''
🔍 AKAM 데이터 다운로드 중...
[*********************100%***********************]  1 of 1 completed
🎯 AKAM df_slice 인덱스 타입: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
🎯 AKAM 컬럼 목록: ['Open', 'High', 'Low', 'Close']
🎯 AKAM dtypes:
Open     float64
High     float64
Low      float64
Close    float64
dtype: object
🎯 AKAM 데이터 샘플:
                 Open       High        Low      Close
Date                                                  
2025-05-01  81.300003  81.930000  80.330002  81.110001
2025-05-02  82.209999  83.040001  81.639999  82.540001
2025-05-05  82.169998  84.050003  81.910004  83.099998
2025-05-06  82.540001  83.559998  82.150002  82.870003
2025-05-07  82.839996  83.440002  82.169998  82.860001
✅ 저장 완료: surge/AKAM_2025-05-08.png
'''
